# %%
from nltk.corpus import movie_reviews

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
#  'neg/cv038_9781.txt',
#  'neg/cv039_5963.txt',
#  'neg/cv040_8829.txt',
#  'neg/cv041_22364.txt',
#  'neg/cv042_11927.txt',
#  'neg/cv043_16808.txt',
#  'neg/cv044_18429.txt',
#  'neg/cv045_25077.txt',
#  'neg/cv046_10613.txt',
#  'neg/cv047_18725.txt',
#  'neg/cv048_18380.txt',
#  'neg/cv049_21917.txt',
#  'neg/cv050_12128.txt',
#  'neg/cv051_10751.txt',
#  'neg/cv052_29318.txt',
#  'neg/cv053_23117.txt',
#  'neg/cv054_4101.txt',
#  'neg/cv055_8926.txt',
#  'neg/cv056_14663.txt',
#  'neg/cv057_7962.txt',
#  'neg/cv058_8469.txt',
#  'neg/cv059_28723.txt',
#  'neg/cv060_11754.txt',
#  'neg/cv061_9321.txt',
#  'neg/cv062_24556.txt',
#  'neg/cv063_28852.txt',
#  'neg/cv064_25842.txt',
#  'neg/cv065_16909.txt',
#  'neg/cv066_11668.txt',
#  'neg/cv067_21192.txt',
#  'neg/cv068_14810.txt',
#  'neg/cv069_11613.txt',
#  'neg/cv070_13249.txt',
#  'neg/cv071_12969.txt',
#  'neg/cv072_5928.txt',
#  'neg/cv073_23039.txt',
#  'neg/cv074_7188.txt',
#  'neg/cv075_6250.txt',
#  'neg/cv076_26009.txt',
#  'neg/cv077_23172.txt',
#  'neg/cv078_16506.txt',
#  'neg/cv079_12766.txt',
#  'neg/cv080_14899.txt',
#  'neg/cv081_18241.txt',
#  'neg/cv082_11979.txt',
#  'neg/cv083_25491.txt',
#  'neg/cv084_15183.txt',
#  'neg/cv085_15286.txt',
#  'neg/cv086_19488.txt',
#  'neg/cv087_2145.txt',
#  'neg/cv088_25274.txt',
#  'neg/cv089_12222.txt',
#  'neg/cv090_0049.txt',
#  'neg/cv091_7899.txt',
#  'neg/cv092_27987.txt',
#  'neg/cv093_15606.txt',
#  'neg/cv094_27868.txt',
#  'neg/cv095_28730.txt',
#  'neg/cv096_12262.txt',
#  'neg/cv097_26081.txt',
#  'neg/cv098_17021.txt',
#  'neg/cv099_11189.txt',
#  'neg/cv100_12406.txt',
#  'neg/cv101_10537.txt',
#  'neg/cv102_8306.txt',
#  'neg/cv103_11943.txt',
#  'neg/cv104_19176.txt',
#  'neg/cv105_19135.txt',
#  'neg/cv106_18379.txt',
#  'neg/cv107_25639.txt',
#  'neg/cv108_17064.txt',
#  'neg/cv109_22599.txt',
#  'neg/cv110_27832.txt',
#  'neg/cv111_12253.txt',
#  'neg/cv112_12178.txt',
#  'neg/cv113_24354.txt',
#  'neg/cv114_19501.txt',
#  'neg/cv115_26443.txt',
#  'neg/cv116_28734.txt',
#  'neg/cv117_25625.txt',
#  'neg/cv118_28837.txt',
#  'neg/cv119_9909.txt',
#  'neg/cv120_3793.txt',
#  'neg/cv121_18621.txt',
#  'neg/cv122_7891.txt',
#  'neg/cv123_12165.txt',
#  'neg/cv124_3903.txt',
#  'neg/cv125_9636.txt',
#  'neg/cv126_28821.txt',
#  'neg/cv127_16451.txt',
#  'neg/cv128_29444.txt',
#  'neg/cv129_18373.txt',
#  'neg/cv130_18521.txt',
#  'neg/cv131_11568.txt',
#  'neg/cv132_5423.txt',
#  'neg/cv133_18065.txt',
#  'neg/cv134_23300.txt',
#  'neg/cv135_12506.txt',
#  'neg/cv136_12384.txt',
#  'neg/cv137_17020.txt',
#  'neg/cv138_13903.txt',
#  'neg/cv139_14236.txt',
#  'neg/cv140_7963.txt',
#  'neg/cv141_17179.txt',
#  'neg/cv142_23657.txt',
#  'neg/cv143_21158.txt',
#  'neg/cv144_5010.txt',
#  'neg/cv145_12239.txt',
#  'neg/cv146_19587.txt',
#  'neg/cv147_22625.txt',
#  'neg/cv148_18084.txt',
#  'neg/cv149_17084.txt',
#  'neg/cv150_14279.txt',
#  'neg/cv151_17231.txt',
#  'neg/cv152_9052.txt',
#  'neg/cv153_11607.txt',
#  'neg/cv154_9562.txt',
#  'neg/cv155_7845.txt',
#  'neg/cv156_11119.txt',
#  'neg/cv157_29302.txt',
#  'neg/cv158_10914.txt',
#  'neg/cv159_29374.txt',
#  'neg/cv160_10848.txt',
#  'neg/cv161_12224.txt',
#  'neg/cv162_10977.txt',
#  'neg/cv163_10110.txt',
#  'neg/cv164_23451.txt',
#  'neg/cv165_2389.txt',
#  'neg/cv166_11959.txt',
#  'neg/cv167_18094.txt',
#  'neg/cv168_7435.txt',
#  'neg/cv169_24973.txt',
#  'neg/cv170_29808.txt',
#  'neg/cv171_15164.txt',
#  'neg/cv172_12037.txt',
#  'neg/cv173_4295.txt',
#  'neg/cv174_9735.txt',
#  'neg/cv175_7375.txt',
#  'neg/cv176_14196.txt',
#  'neg/cv177_10904.txt',
#  'neg/cv178_14380.txt',
#  'neg/cv179_9533.txt',
#  'neg/cv180_17823.txt',
#  'neg/cv181_16083.txt',
#  'neg/cv182_7791.txt',
#  'neg/cv183_19826.txt',
#  'neg/cv184_26935.txt',
#  'neg/cv185_28372.txt',
#  'neg/cv186_2396.txt',
#  'neg/cv187_14112.txt',
#  'neg/cv188_20687.txt',
#  'neg/cv189_24248.txt',
#  'neg/cv190_27176.txt',
#  'neg/cv191_29539.txt',
#  'neg/cv192_16079.txt',
#  'neg/cv193_5393.txt',
#  'neg/cv194_12855.txt',
#  'neg/cv195_16146.txt',
#  'neg/cv196_28898.txt',
#  'neg/cv197_29271.txt',
#  'neg/cv198_19313.txt',
#  'neg/cv199_9721.txt',
#  'neg/cv200_29006.txt',
#  'neg/cv201_7421.txt',
#  'neg/cv202_11382.txt',
#  'neg/cv203_19052.txt',
#  'neg/cv204_8930.txt',
#  'neg/cv205_9676.txt',
#  'neg/cv206_15893.txt',
#  'neg/cv207_29141.txt',
#  'neg/cv208_9475.txt',
#  'neg/cv209_28973.txt',
#  'neg/cv210_9557.txt',
#  'neg/cv211_9955.txt',
#  'neg/cv212_10054.txt',
#  'neg/cv213_20300.txt',
#  'neg/cv214_13285.txt',
#  'neg/cv215_23246.txt',
#  'neg/cv216_20165.txt',
#  'neg/cv217_28707.txt',
#  'neg/cv218_25651.txt',
#  'neg/cv219_19874.txt',
#  'neg/cv220_28906.txt',
#  'neg/cv221_27081.txt',
#  'neg/cv222_18720.txt',
#  'neg/cv223_28923.txt',
#  'neg/cv224_18875.txt',
#  'neg/cv225_29083.txt',
#  'neg/cv226_26692.txt',
#  'neg/cv227_25406.txt',
#  'neg/cv228_5644.txt',
#  'neg/cv229_15200.txt',
#  'neg/cv230_7913.txt',
#  'neg/cv231_11028.txt',
#  'neg/cv232_16768.txt',
#  'neg/cv233_17614.txt',
#  'neg/cv234_22123.txt',
#  'neg/cv235_10704.txt',
#  'neg/cv236_12427.txt',
#  'neg/cv237_20635.txt',
#  'neg/cv238_14285.txt',
#  'neg/cv239_29828.txt',
#  'neg/cv240_15948.txt',
#  'neg/cv241_24602.txt',
#  'neg/cv242_11354.txt',
#  'neg/cv243_22164.txt',
#  'neg/cv244_22935.txt',
#  'neg/cv245_8938.txt',
#  'neg/cv246_28668.txt',
#  'neg/cv247_14668.txt',
#  'neg/cv248_15672.txt',
#  'neg/cv249_12674.txt',
#  'neg/cv250_26462.txt',
#  'neg/cv251_23901.txt',
#  'neg/cv252_24974.txt',
#  'neg/cv253_10190.txt',
#  'neg/cv254_5870.txt',
#  'neg/cv255_15267.txt',
#  'neg/cv256_16529.txt',
#  'neg/cv257_11856.txt',
#  'neg/cv258_5627.txt',
#  'neg/cv259_11827.txt',
#  'neg/cv260_15652.txt',
#  'neg/cv261_11855.txt',
#  'neg/cv262_13812.txt',
#  'neg/cv263_20693.txt',
#  'neg/cv264_14108.txt',
#  'neg/cv265_11625.txt',
#  'neg/cv266_26644.txt',
#  'neg/cv267_16618.txt',
#  'neg/cv268_20288.txt',
#  'neg/cv269_23018.txt',
#  'neg/cv270_5873.txt',
#  'neg/cv271_15364.txt',
#  'neg/cv272_20313.txt',
#  'neg/cv273_28961.txt',
#  'neg/cv274_26379.txt',
#  'neg/cv275_28725.txt',
#  'neg/cv276_17126.txt',
#  'neg/cv277_20467.txt',
#  'neg/cv278_14533.txt',
#  'neg/cv279_19452.txt',
#  'neg/cv280_8651.txt',
#  'neg/cv281_24711.txt',
#  'neg/cv282_6833.txt',
#  'neg/cv283_11963.txt',
#  'neg/cv284_20530.txt',
#  'neg/cv285_18186.txt',
#  'neg/cv286_26156.txt',
#  'neg/cv287_17410.txt',
#  'neg/cv288_20212.txt',
#  'neg/cv289_6239.txt',
#  'neg/cv290_11981.txt',
#  'neg/cv291_26844.txt',
#  'neg/cv292_7804.txt',
#  'neg/cv293_29731.txt',
#  'neg/cv294_12695.txt',
#  'neg/cv295_17060.txt',
#  'neg/cv296_13146.txt',
#  'neg/cv297_10104.txt',
#  'neg/cv298_24487.txt',
#  'neg/cv299_17950.txt',
#  'neg/cv300_23302.txt',
#  'neg/cv301_13010.txt',
#  'neg/cv302_26481.txt',
#  'neg/cv303_27366.txt',
#  'neg/cv304_28489.txt',
#  'neg/cv305_9937.txt',
#  'neg/cv306_10859.txt',
#  'neg/cv307_26382.txt',
#  'neg/cv308_5079.txt',
#  'neg/cv309_23737.txt',
#  'neg/cv310_14568.txt',
#  'neg/cv311_17708.txt',
#  'neg/cv312_29308.txt',
#  'neg/cv313_19337.txt',
#  'neg/cv314_16095.txt',
#  'neg/cv315_12638.txt',
#  'neg/cv316_5972.txt',
#  'neg/cv317_25111.txt',
#  'neg/cv318_11146.txt',
#  'neg/cv319_16459.txt',
#  'neg/cv320_9693.txt',
#  'neg/cv321_14191.txt',
#  'neg/cv322_21820.txt',
#  'neg/cv323_29633.txt',
#  'neg/cv324_7502.txt',
#  'neg/cv325_18330.txt',
#  'neg/cv326_14777.txt',
#  'neg/cv327_21743.txt',
#  'neg/cv328_10908.txt',
#  'neg/cv329_29293.txt',
#  'neg/cv330_29675.txt',
#  'neg/cv331_8656.txt',
#  'neg/cv332_17997.txt',
#  'neg/cv333_9443.txt',
#  'neg/cv334_0074.txt',
#  'neg/cv335_16299.txt',
#  'neg/cv336_10363.txt',
#  'neg/cv337_29061.txt',
#  'neg/cv338_9183.txt',
#  'neg/cv339_22452.txt',
#  'neg/cv340_14776.txt',
#  'neg/cv341_25667.txt',
#  'neg/cv342_20917.txt',
#  'neg/cv343_10906.txt',
#  'neg/cv344_5376.txt',
#  'neg/cv345_9966.txt',
#  'neg/cv346_19198.txt',
#  'neg/cv347_14722.txt',
#  'neg/cv348_19207.txt',
#  'neg/cv349_15032.txt',
#  'neg/cv350_22139.txt',
#  'neg/cv351_17029.txt',
#  'neg/cv352_5414.txt',
#  'neg/cv353_19197.txt',
#  'neg/cv354_8573.txt',
#  'neg/cv355_18174.txt',
#  'neg/cv356_26170.txt',
#  'neg/cv357_14710.txt',
#  'neg/cv358_11557.txt',
#  'neg/cv359_6751.txt',
#  'neg/cv360_8927.txt',
#  'neg/cv361_28738.txt',
#  'neg/cv362_16985.txt',
#  'neg/cv363_29273.txt',
#  'neg/cv364_14254.txt',
#  'neg/cv365_12442.txt',
#  'neg/cv366_10709.txt',
#  'neg/cv367_24065.txt',
#  'neg/cv368_11090.txt',
#  'neg/cv369_14245.txt',
#  'neg/cv370_5338.txt',
#  'neg/cv371_8197.txt',
#  'neg/cv372_6654.txt',
#  'neg/cv373_21872.txt',
#  'neg/cv374_26455.txt',
#  'neg/cv375_9932.txt',
#  'neg/cv376_20883.txt',
#  'neg/cv377_8440.txt',
#  'neg/cv378_21982.txt',
#  'neg/cv379_23167.txt',
#  'neg/cv380_8164.txt',
#  'neg/cv381_21673.txt',
#  'neg/cv382_8393.txt',
#  'neg/cv383_14662.txt',
#  'neg/cv384_18536.txt',
#  'neg/cv385_29621.txt',
#  'neg/cv386_10229.txt',
#  'neg/cv387_12391.txt',
#  'neg/cv388_12810.txt',
#  'neg/cv389_9611.txt',
#  'neg/cv390_12187.txt',
#  'neg/cv391_11615.txt',
#  'neg/cv392_12238.txt',
#  'neg/cv393_29234.txt',
#  'neg/cv394_5311.txt',
#  'neg/cv395_11761.txt',
#  'neg/cv396_19127.txt',
#  'neg/cv397_28890.txt',
#  'neg/cv398_17047.txt',
#  'neg/cv399_28593.txt',
#  'neg/cv400_20631.txt',
#  'neg/cv401_13758.txt',
#  'neg/cv402_16097.txt',
#  'neg/cv403_6721.txt',
#  'neg/cv404_21805.txt',
#  'neg/cv405_21868.txt',
#  'neg/cv406_22199.txt',
#  'neg/cv407_23928.txt',
#  'neg/cv408_5367.txt',
#  'neg/cv409_29625.txt',
#  'neg/cv410_25624.txt',
#  'neg/cv411_16799.txt',
#  'neg/cv412_25254.txt',
#  'neg/cv413_7893.txt',
#  'neg/cv414_11161.txt',
#  'neg/cv415_23674.txt',
#  'neg/cv416_12048.txt',
#  'neg/cv417_14653.txt',
#  'neg/cv418_16562.txt',
#  'neg/cv419_14799.txt',
#  'neg/cv420_28631.txt',
#  'neg/cv421_9752.txt',
#  'neg/cv422_9632.txt',
#  'neg/cv423_12089.txt',
#  'neg/cv424_9268.txt',
#  'neg/cv425_8603.txt',
#  'neg/cv426_10976.txt',
#  'neg/cv427_11693.txt',
#  'neg/cv428_12202.txt',
#  'neg/cv429_7937.txt',
#  'neg/cv430_18662.txt',
#  'neg/cv431_7538.txt',
#  'neg/cv432_15873.txt',
#  'neg/cv433_10443.txt',
#  'neg/cv434_5641.txt',
#  'neg/cv435_24355.txt',
#  'neg/cv436_20564.txt',
#  'neg/cv437_24070.txt',
#  'neg/cv438_8500.txt',
#  'neg/cv439_17633.txt',
#  'neg/cv440_16891.txt',
#  'neg/cv441_15276.txt',
#  'neg/cv442_15499.txt',
#  'neg/cv443_22367.txt',
#  'neg/cv444_9975.txt',
#  'neg/cv445_26683.txt',
#  'neg/cv446_12209.txt',
#  'neg/cv447_27334.txt',
#  'neg/cv448_16409.txt',
#  'neg/cv449_9126.txt',
#  'neg/cv450_8319.txt',
#  'neg/cv451_11502.txt',
#  'neg/cv452_5179.txt',
#  'neg/cv453_10911.txt',
#  'neg/cv454_21961.txt',
#  'neg/cv455_28866.txt',
#  'neg/cv456_20370.txt',
#  'neg/cv457_19546.txt',
#  'neg/cv458_9000.txt',
#  'neg/cv459_21834.txt',
#  'neg/cv460_11723.txt',
#  'neg/cv461_21124.txt',
#  'neg/cv462_20788.txt',
#  'neg/cv463_10846.txt',
#  'neg/cv464_17076.txt',
#  'neg/cv465_23401.txt',
#  'neg/cv466_20092.txt',
#  'neg/cv467_26610.txt',
#  'neg/cv468_16844.txt',
#  'neg/cv469_21998.txt',
#  'neg/cv470_17444.txt',
#  'neg/cv471_18405.txt',
#  'neg/cv472_29140.txt',
#  'neg/cv473_7869.txt',
#  'neg/cv474_10682.txt',
#  'neg/cv475_22978.txt',
#  'neg/cv476_18402.txt',
#  'neg/cv477_23530.txt',
#  'neg/cv478_15921.txt',
#  'neg/cv479_5450.txt',
#  'neg/cv480_21195.txt',
#  'neg/cv481_7930.txt',
#  'neg/cv482_11233.txt',
#  'neg/cv483_18103.txt',
#  'neg/cv484_26169.txt',
#  'neg/cv485_26879.txt',
#  'neg/cv486_9788.txt',
#  'neg/cv487_11058.txt',
#  'neg/cv488_21453.txt',
#  'neg/cv489_19046.txt',
#  'neg/cv490_18986.txt',
#  'neg/cv491_12992.txt',
#  'neg/cv492_19370.txt',
#  'neg/cv493_14135.txt',
#  'neg/cv494_18689.txt',
#  'neg/cv495_16121.txt',
#  'neg/cv496_11185.txt',
#  'neg/cv497_27086.txt',
#  'neg/cv498_9288.txt',
#  'neg/cv499_11407.txt',
#  'neg/cv500_10722.txt',
#  'neg/cv501_12675.txt',
#  'neg/cv502_10970.txt',
#  'neg/cv503_11196.txt',
#  'neg/cv504_29120.txt',
#  'neg/cv505_12926.txt',
#  'neg/cv506_17521.txt',
#  'neg/cv507_9509.txt',
#  'neg/cv508_17742.txt',
#  'neg/cv509_17354.txt',
#  'neg/cv510_24758.txt',
#  'neg/cv511_10360.txt',
#  'neg/cv512_17618.txt',
#  'neg/cv513_7236.txt',
#  'neg/cv514_12173.txt',
#  'neg/cv515_18484.txt',
#  'neg/cv516_12117.txt',
#  'neg/cv517_20616.txt',
#  'neg/cv518_14798.txt',
#  'neg/cv519_16239.txt',
#  'neg/cv520_13297.txt',
#  'neg/cv521_1730.txt',
#  'neg/cv522_5418.txt',
#  'neg/cv523_18285.txt',
#  'neg/cv524_24885.txt',
#  'neg/cv525_17930.txt',
#  'neg/cv526_12868.txt',
#  'neg/cv527_10338.txt',
#  'neg/cv528_11669.txt',
#  'neg/cv529_10972.txt',
#  'neg/cv530_17949.txt',
#  'neg/cv531_26838.txt',
#  'neg/cv532_6495.txt',
#  'neg/cv533_9843.txt',
#  'neg/cv534_15683.txt',
#  'neg/cv535_21183.txt',
#  'neg/cv536_27221.txt',
#  'neg/cv537_13516.txt',
#  'neg/cv538_28485.txt',
#  'neg/cv539_21865.txt',
#  'neg/cv540_3092.txt',
#  'neg/cv541_28683.txt',
#  'neg/cv542_20359.txt',
#  'neg/cv543_5107.txt',
#  'neg/cv544_5301.txt',
#  'neg/cv545_12848.txt',
#  'neg/cv546_12723.txt',
#  'neg/cv547_18043.txt',
#  'neg/cv548_18944.txt',
#  'neg/cv549_22771.txt',
#  'neg/cv550_23226.txt',
#  'neg/cv551_11214.txt',
#  'neg/cv552_0150.txt',
#  'neg/cv553_26965.txt',
#  'neg/cv554_14678.txt',
#  'neg/cv555_25047.txt',
#  'neg/cv556_16563.txt',
#  'neg/cv557_12237.txt',
#  'neg/cv558_29376.txt',
#  'neg/cv559_0057.txt',
#  'neg/cv560_18608.txt',
#  'neg/cv561_9484.txt',
#  'neg/cv562_10847.txt',
#  'neg/cv563_18610.txt',
#  'neg/cv564_12011.txt',
#  'neg/cv565_29403.txt',
#  'neg/cv566_8967.txt',
#  'neg/cv567_29420.txt',
#  'neg/cv568_17065.txt',
#  'neg/cv569_26750.txt',
#  'neg/cv570_28960.txt',
#  'neg/cv571_29292.txt',
#  'neg/cv572_20053.txt',
#  'neg/cv573_29384.txt',
#  'neg/cv574_23191.txt',
#  'neg/cv575_22598.txt',
#  'neg/cv576_15688.txt',
#  'neg/cv577_28220.txt',
#  'neg/cv578_16825.txt',
#  'neg/cv579_12542.txt',
#  'neg/cv580_15681.txt',
#  'neg/cv581_20790.txt',
#  'neg/cv582_6678.txt',
#  'neg/cv583_29465.txt',
#  'neg/cv584_29549.txt',
#  'neg/cv585_23576.txt',
#  'neg/cv586_8048.txt',
#  'neg/cv587_20532.txt',
#  'neg/cv588_14467.txt',
#  'neg/cv589_12853.txt',
#  'neg/cv590_20712.txt',
#  'neg/cv591_24887.txt',
#  'neg/cv592_23391.txt',
#  'neg/cv593_11931.txt',
#  'neg/cv594_11945.txt',
#  'neg/cv595_26420.txt',
#  'neg/cv596_4367.txt',
#  'neg/cv597_26744.txt',
#  'neg/cv598_18184.txt',
#  'neg/cv599_22197.txt',
#  'neg/cv600_25043.txt',
#  'neg/cv601_24759.txt',
#  'neg/cv602_8830.txt',
#  'neg/cv603_18885.txt',
#  'neg/cv604_23339.txt',
#  'neg/cv605_12730.txt',
#  'neg/cv606_17672.txt',
#  'neg/cv607_8235.txt',
#  'neg/cv608_24647.txt',
#  'neg/cv609_25038.txt',
#  'neg/cv610_24153.txt',
#  'neg/cv611_2253.txt',
#  'neg/cv612_5396.txt',
#  'neg/cv613_23104.txt',
#  'neg/cv614_11320.txt',
#  'neg/cv615_15734.txt',
#  'neg/cv616_29187.txt',
#  'neg/cv617_9561.txt',
#  'neg/cv618_9469.txt',
#  'neg/cv619_13677.txt',
#  'neg/cv620_2556.txt',
#  'neg/cv621_15984.txt',
#  'neg/cv622_8583.txt',
#  'neg/cv623_16988.txt',
#  'neg/cv624_11601.txt',
#  'neg/cv625_13518.txt',
#  'neg/cv626_7907.txt',
#  'neg/cv627_12603.txt',
#  'neg/cv628_20758.txt',
#  'neg/cv629_16604.txt',
#  'neg/cv630_10152.txt',
#  'neg/cv631_4782.txt',
#  'neg/cv632_9704.txt',
#  'neg/cv633_29730.txt',
#  'neg/cv634_11989.txt',
#  'neg/cv635_0984.txt',
#  'neg/cv636_16954.txt',
#  'neg/cv637_13682.txt',
#  'neg/cv638_29394.txt',
#  'neg/cv639_10797.txt',
#  'neg/cv640_5380.txt',
#  'neg/cv641_13412.txt',
#  'neg/cv642_29788.txt',
#  'neg/cv643_29282.txt',
#  'neg/cv644_18551.txt',
#  'neg/cv645_17078.txt',
#  'neg/cv646_16817.txt',
#  'neg/cv647_15275.txt',
#  'neg/cv648_17277.txt',
#  'neg/cv649_13947.txt',
#  'neg/cv650_15974.txt',
#  'neg/cv651_11120.txt',
#  'neg/cv652_15653.txt',
#  'neg/cv653_2107.txt',
#  'neg/cv654_19345.txt',
#  'neg/cv655_12055.txt',
#  'neg/cv656_25395.txt',
#  'neg/cv657_25835.txt',
#  'neg/cv658_11186.txt',
#  'neg/cv659_21483.txt',
#  'neg/cv660_23140.txt',
#  'neg/cv661_25780.txt',
#  'neg/cv662_14791.txt',
#  'neg/cv663_14484.txt',
#  'neg/cv664_4264.txt',
#  'neg/cv665_29386.txt',
#  'neg/cv666_20301.txt',
#  'neg/cv667_19672.txt',
#  'neg/cv668_18848.txt',
#  'neg/cv669_24318.txt',
#  'neg/cv670_2666.txt',
#  'neg/cv671_5164.txt',
#  'neg/cv672_27988.txt',
#  'neg/cv673_25874.txt',
#  'neg/cv674_11593.txt',
#  'neg/cv675_22871.txt',
#  'neg/cv676_22202.txt',
#  'neg/cv677_18938.txt',
#  'neg/cv678_14887.txt',
#  'neg/cv679_28221.txt',
#  'neg/cv680_10533.txt',
#  'neg/cv681_9744.txt',
#  'neg/cv682_17947.txt',
#  'neg/cv683_13047.txt',
#  'neg/cv684_12727.txt',
#  'neg/cv685_5710.txt',
#  'neg/cv686_15553.txt',
#  'neg/cv687_22207.txt',
#  'neg/cv688_7884.txt',
#  'neg/cv689_13701.txt',
#  'neg/cv690_5425.txt',
#  'neg/cv691_5090.txt',
#  'neg/cv692_17026.txt',
#  'neg/cv693_19147.txt',
#  'neg/cv694_4526.txt',
#  'neg/cv695_22268.txt',
#  'neg/cv696_29619.txt',
#  'neg/cv697_12106.txt',
#  'neg/cv698_16930.txt',
#  'neg/cv699_7773.txt',
#  'neg/cv700_23163.txt',
#  'neg/cv701_15880.txt',
#  'neg/cv702_12371.txt',
#  'neg/cv703_17948.txt',
#  'neg/cv704_17622.txt',
#  'neg/cv705_11973.txt',
#  'neg/cv706_25883.txt',
#  'neg/cv707_11421.txt',
#  'neg/cv708_28539.txt',
#  'neg/cv709_11173.txt',
#  'neg/cv710_23745.txt',
#  'neg/cv711_12687.txt',
#  'neg/cv712_24217.txt',
#  'neg/cv713_29002.txt',
#  'neg/cv714_19704.txt',
#  'neg/cv715_19246.txt',
#  'neg/cv716_11153.txt',
#  'neg/cv717_17472.txt',
#  'neg/cv718_12227.txt',
#  'neg/cv719_5581.txt',
#  'neg/cv720_5383.txt',
#  'neg/cv721_28993.txt',
#  'neg/cv722_7571.txt',
#  'neg/cv723_9002.txt',
#  'neg/cv724_15265.txt',
#  'neg/cv725_10266.txt',
#  'neg/cv726_4365.txt',
#  'neg/cv727_5006.txt',
#  'neg/cv728_17931.txt',
#  'neg/cv729_10475.txt',
#  'neg/cv730_10729.txt',
#  'neg/cv731_3968.txt',
#  'neg/cv732_13092.txt',
#  'neg/cv733_9891.txt',
#  'neg/cv734_22821.txt',
#  'neg/cv735_20218.txt',
#  'neg/cv736_24947.txt',
#  'neg/cv737_28733.txt',
#  'neg/cv738_10287.txt',
#  'neg/cv739_12179.txt',
#  'neg/cv740_13643.txt',
#  'neg/cv741_12765.txt',
#  'neg/cv742_8279.txt',
#  'neg/cv743_17023.txt',
#  'neg/cv744_10091.txt',
#  'neg/cv745_14009.txt',
#  'neg/cv746_10471.txt',
#  'neg/cv747_18189.txt',
#  'neg/cv748_14044.txt',
#  'neg/cv749_18960.txt',
#  'neg/cv750_10606.txt',
#  'neg/cv751_17208.txt',
#  'neg/cv752_25330.txt',
#  'neg/cv753_11812.txt',
#  'neg/cv754_7709.txt',
#  'neg/cv755_24881.txt',
#  'neg/cv756_23676.txt',
#  'neg/cv757_10668.txt',
#  'neg/cv758_9740.txt',
#  'neg/cv759_15091.txt',
#  'neg/cv760_8977.txt',
#  'neg/cv761_13769.txt',
#  'neg/cv762_15604.txt',
#  'neg/cv763_16486.txt',
#  'neg/cv764_12701.txt',
#  'neg/cv765_20429.txt',
#  'neg/cv766_7983.txt',
#  'neg/cv767_15673.txt',
#  'neg/cv768_12709.txt',
#  'neg/cv769_8565.txt',
#  'neg/cv770_11061.txt',
#  'neg/cv771_28466.txt',
#  'neg/cv772_12971.txt',
#  'neg/cv773_20264.txt',
#  'neg/cv774_15488.txt',
#  'neg/cv775_17966.txt',
#  'neg/cv776_21934.txt',
#  'neg/cv777_10247.txt',
#  'neg/cv778_18629.txt',
#  'neg/cv779_18989.txt',
#  'neg/cv780_8467.txt',
#  'neg/cv781_5358.txt',
#  'neg/cv782_21078.txt',
#  'neg/cv783_14724.txt',
#  'neg/cv784_16077.txt',
#  'neg/cv785_23748.txt',
#  'neg/cv786_23608.txt',
#  'neg/cv787_15277.txt',
#  'neg/cv788_26409.txt',
#  'neg/cv789_12991.txt',
#  'neg/cv790_16202.txt',
#  'neg/cv791_17995.txt',
#  'neg/cv792_3257.txt',
#  'neg/cv793_15235.txt',
#  'neg/cv794_17353.txt',
#  'neg/cv795_10291.txt',
#  'neg/cv796_17243.txt',
#  'neg/cv797_7245.txt',
#  'neg/cv798_24779.txt',
#  'neg/cv799_19812.txt',
#  'neg/cv800_13494.txt',
#  'neg/cv801_26335.txt',
#  'neg/cv802_28381.txt',
#  'neg/cv803_8584.txt',
#  'neg/cv804_11763.txt',
#  'neg/cv805_21128.txt',
#  'neg/cv806_9405.txt',
#  'neg/cv807_23024.txt',
#  'neg/cv808_13773.txt',
#  'neg/cv809_5012.txt',
#  'neg/cv810_13660.txt',
#  'neg/cv811_22646.txt',
#  'neg/cv812_19051.txt',
#  'neg/cv813_6649.txt',
#  'neg/cv814_20316.txt',
#  'neg/cv815_23466.txt',
#  'neg/cv816_15257.txt',
#  'neg/cv817_3675.txt',
#  'neg/cv818_10698.txt',
#  'neg/cv819_9567.txt',
#  'neg/cv820_24157.txt',
#  'neg/cv821_29283.txt',
#  'neg/cv822_21545.txt',
#  'neg/cv823_17055.txt',
#  'neg/cv824_9335.txt',
#  'neg/cv825_5168.txt',
#  'neg/cv826_12761.txt',
#  'neg/cv827_19479.txt',
#  'neg/cv828_21392.txt',
#  'neg/cv829_21725.txt',
#  'neg/cv830_5778.txt',
#  'neg/cv831_16325.txt',
#  'neg/cv832_24713.txt',
#  'neg/cv833_11961.txt',
#  'neg/cv834_23192.txt',
#  'neg/cv835_20531.txt',
#  'neg/cv836_14311.txt',
#  'neg/cv837_27232.txt',
#  'neg/cv838_25886.txt',
#  'neg/cv839_22807.txt',
#  'neg/cv840_18033.txt',
#  'neg/cv841_3367.txt',
#  'neg/cv842_5702.txt',
#  'neg/cv843_17054.txt',
#  'neg/cv844_13890.txt',
#  'neg/cv845_15886.txt',
#  'neg/cv846_29359.txt',
#  'neg/cv847_20855.txt',
#  'neg/cv848_10061.txt',
#  'neg/cv849_17215.txt',
#  'neg/cv850_18185.txt',
#  'neg/cv851_21895.txt',
#  'neg/cv852_27512.txt',
#  'neg/cv853_29119.txt',
#  'neg/cv854_18955.txt',
#  'neg/cv855_22134.txt',
#  'neg/cv856_28882.txt',
#  'neg/cv857_17527.txt',
#  'neg/cv858_20266.txt',
#  'neg/cv859_15689.txt',
#  'neg/cv860_15520.txt',
#  'neg/cv861_12809.txt',
#  'neg/cv862_15924.txt',
#  'neg/cv863_7912.txt',
#  'neg/cv864_3087.txt',
#  'neg/cv865_28796.txt',
#  'neg/cv866_29447.txt',
#  'neg/cv867_18362.txt',
#  'neg/cv868_12799.txt',
#  'neg/cv869_24782.txt',
#  'neg/cv870_18090.txt',
#  'neg/cv871_25971.txt',
#  'neg/cv872_13710.txt',
#  'neg/cv873_19937.txt',
#  'neg/cv874_12182.txt',
#  'neg/cv875_5622.txt',
#  'neg/cv876_9633.txt',
#  'neg/cv877_29132.txt',
#  'neg/cv878_17204.txt',
#  'neg/cv879_16585.txt',
#  'neg/cv880_29629.txt',
#  'neg/cv881_14767.txt',
#  'neg/cv882_10042.txt',
#  'neg/cv883_27621.txt',
#  'neg/cv884_15230.txt',
#  'neg/cv885_13390.txt',
#  'neg/cv886_19210.txt',
#  'neg/cv887_5306.txt',
#  'neg/cv888_25678.txt',
#  'neg/cv889_22670.txt',
#  'neg/cv890_3515.txt',
#  'neg/cv891_6035.txt',
#  'neg/cv892_18788.txt',
#  'neg/cv893_26731.txt',
#  'neg/cv894_22140.txt',
#  'neg/cv895_22200.txt',
#  'neg/cv896_17819.txt',
#  'neg/cv897_11703.txt',
#  'neg/cv898_1576.txt',
#  'neg/cv899_17812.txt',
#  'neg/cv900_10800.txt',
#  'neg/cv901_11934.txt',
#  'neg/cv902_13217.txt',
#  'neg/cv903_18981.txt',
#  'neg/cv904_25663.txt',
#  'neg/cv905_28965.txt',
#  'neg/cv906_12332.txt',
#  'neg/cv907_3193.txt',
#  'neg/cv908_17779.txt',
#  'neg/cv909_9973.txt',
#  'neg/cv910_21930.txt',
#  'neg/cv911_21695.txt',
#  'neg/cv912_5562.txt',
#  'neg/cv913_29127.txt',
#  'neg/cv914_2856.txt',
#  'neg/cv915_9342.txt',
#  'neg/cv916_17034.txt',
#  'neg/cv917_29484.txt',
#  'neg/cv918_27080.txt',
#  'neg/cv919_18155.txt',
#  'neg/cv920_29423.txt',
#  'neg/cv921_13988.txt',
#  'neg/cv922_10185.txt',
#  'neg/cv923_11951.txt',
#  'neg/cv924_29397.txt',
#  'neg/cv925_9459.txt',
#  'neg/cv926_18471.txt',
#  'neg/cv927_11471.txt',
#  'neg/cv928_9478.txt',
#  'neg/cv929_1841.txt',
#  'neg/cv930_14949.txt',
#  'neg/cv931_18783.txt',
#  'neg/cv932_14854.txt',
#  'neg/cv933_24953.txt',
#  'neg/cv934_20426.txt',
#  'neg/cv935_24977.txt',
#  'neg/cv936_17473.txt',
#  'neg/cv937_9816.txt',
#  'neg/cv938_10706.txt',
#  'neg/cv939_11247.txt',
#  'neg/cv940_18935.txt',
#  'neg/cv941_10718.txt',
#  'neg/cv942_18509.txt',
#  'neg/cv943_23547.txt',
#  'neg/cv944_15042.txt',
#  'neg/cv945_13012.txt',
#  'neg/cv946_20084.txt',
#  'neg/cv947_11316.txt',
#  'neg/cv948_25870.txt',
#  'neg/cv949_21565.txt',
#  'neg/cv950_13478.txt',
#  'neg/cv951_11816.txt',
#  'neg/cv952_26375.txt',
#  'neg/cv953_7078.txt',
#  'neg/cv954_19932.txt',
#  'neg/cv955_26154.txt',
#  'neg/cv956_12547.txt',
#  'neg/cv957_9059.txt',
#  'neg/cv958_13020.txt',
#  'neg/cv959_16218.txt',
#  'neg/cv960_28877.txt',
#  'neg/cv961_5578.txt',
#  'neg/cv962_9813.txt',
#  'neg/cv963_7208.txt',
#  'neg/cv964_5794.txt',
#  'neg/cv965_26688.txt',
#  'neg/cv966_28671.txt',
#  'neg/cv967_5626.txt',
#  'neg/cv968_25413.txt',
#  'neg/cv969_14760.txt',
#  'neg/cv970_19532.txt',
#  'neg/cv971_11790.txt',
#  'neg/cv972_26837.txt',
#  'neg/cv973_10171.txt',
#  'neg/cv974_24303.txt',
#  'neg/cv975_11920.txt',
#  'neg/cv976_10724.txt',
#  'neg/cv977_4776.txt',
#  'neg/cv978_22192.txt',
#  'neg/cv979_2029.txt',
#  'neg/cv980_11851.txt',
#  'neg/cv981_16679.txt',
#  'neg/cv982_22209.txt',
#  'neg/cv983_24219.txt',
#  'neg/cv984_14006.txt',
#  'neg/cv985_5964.txt',
#  'neg/cv986_15092.txt',
#  'neg/cv987_7394.txt',
#  'neg/cv988_20168.txt',
#  'neg/cv989_17297.txt',
#  'neg/cv990_12443.txt',
#  'neg/cv991_19973.txt',
#  'neg/cv992_12806.txt',
#  'neg/cv993_29565.txt',
#  'neg/cv994_13229.txt',
#  'neg/cv995_23113.txt',
#  'neg/cv996_12447.txt',
#  'neg/cv997_5152.txt',
#  'neg/cv998_15691.txt',
#  'neg/cv999_14636.txt',
#  ...]

# %%
len(movie_reviews.fileids())
# Out:
# 2000

# %%
movie_reviews.fileids("neg")
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
#  'neg/cv038_9781.txt',
#  'neg/cv039_5963.txt',
#  'neg/cv040_8829.txt',
#  'neg/cv041_22364.txt',
#  'neg/cv042_11927.txt',
#  'neg/cv043_16808.txt',
#  'neg/cv044_18429.txt',
#  'neg/cv045_25077.txt',
#  'neg/cv046_10613.txt',
#  'neg/cv047_18725.txt',
#  'neg/cv048_18380.txt',
#  'neg/cv049_21917.txt',
#  'neg/cv050_12128.txt',
#  'neg/cv051_10751.txt',
#  'neg/cv052_29318.txt',
#  'neg/cv053_23117.txt',
#  'neg/cv054_4101.txt',
#  'neg/cv055_8926.txt',
#  'neg/cv056_14663.txt',
#  'neg/cv057_7962.txt',
#  'neg/cv058_8469.txt',
#  'neg/cv059_28723.txt',
#  'neg/cv060_11754.txt',
#  'neg/cv061_9321.txt',
#  'neg/cv062_24556.txt',
#  'neg/cv063_28852.txt',
#  'neg/cv064_25842.txt',
#  'neg/cv065_16909.txt',
#  'neg/cv066_11668.txt',
#  'neg/cv067_21192.txt',
#  'neg/cv068_14810.txt',
#  'neg/cv069_11613.txt',
#  'neg/cv070_13249.txt',
#  'neg/cv071_12969.txt',
#  'neg/cv072_5928.txt',
#  'neg/cv073_23039.txt',
#  'neg/cv074_7188.txt',
#  'neg/cv075_6250.txt',
#  'neg/cv076_26009.txt',
#  'neg/cv077_23172.txt',
#  'neg/cv078_16506.txt',
#  'neg/cv079_12766.txt',
#  'neg/cv080_14899.txt',
#  'neg/cv081_18241.txt',
#  'neg/cv082_11979.txt',
#  'neg/cv083_25491.txt',
#  'neg/cv084_15183.txt',
#  'neg/cv085_15286.txt',
#  'neg/cv086_19488.txt',
#  'neg/cv087_2145.txt',
#  'neg/cv088_25274.txt',
#  'neg/cv089_12222.txt',
#  'neg/cv090_0049.txt',
#  'neg/cv091_7899.txt',
#  'neg/cv092_27987.txt',
#  'neg/cv093_15606.txt',
#  'neg/cv094_27868.txt',
#  'neg/cv095_28730.txt',
#  'neg/cv096_12262.txt',
#  'neg/cv097_26081.txt',
#  'neg/cv098_17021.txt',
#  'neg/cv099_11189.txt',
#  'neg/cv100_12406.txt',
#  'neg/cv101_10537.txt',
#  'neg/cv102_8306.txt',
#  'neg/cv103_11943.txt',
#  'neg/cv104_19176.txt',
#  'neg/cv105_19135.txt',
#  'neg/cv106_18379.txt',
#  'neg/cv107_25639.txt',
#  'neg/cv108_17064.txt',
#  'neg/cv109_22599.txt',
#  'neg/cv110_27832.txt',
#  'neg/cv111_12253.txt',
#  'neg/cv112_12178.txt',
#  'neg/cv113_24354.txt',
#  'neg/cv114_19501.txt',
#  'neg/cv115_26443.txt',
#  'neg/cv116_28734.txt',
#  'neg/cv117_25625.txt',
#  'neg/cv118_28837.txt',
#  'neg/cv119_9909.txt',
#  'neg/cv120_3793.txt',
#  'neg/cv121_18621.txt',
#  'neg/cv122_7891.txt',
#  'neg/cv123_12165.txt',
#  'neg/cv124_3903.txt',
#  'neg/cv125_9636.txt',
#  'neg/cv126_28821.txt',
#  'neg/cv127_16451.txt',
#  'neg/cv128_29444.txt',
#  'neg/cv129_18373.txt',
#  'neg/cv130_18521.txt',
#  'neg/cv131_11568.txt',
#  'neg/cv132_5423.txt',
#  'neg/cv133_18065.txt',
#  'neg/cv134_23300.txt',
#  'neg/cv135_12506.txt',
#  'neg/cv136_12384.txt',
#  'neg/cv137_17020.txt',
#  'neg/cv138_13903.txt',
#  'neg/cv139_14236.txt',
#  'neg/cv140_7963.txt',
#  'neg/cv141_17179.txt',
#  'neg/cv142_23657.txt',
#  'neg/cv143_21158.txt',
#  'neg/cv144_5010.txt',
#  'neg/cv145_12239.txt',
#  'neg/cv146_19587.txt',
#  'neg/cv147_22625.txt',
#  'neg/cv148_18084.txt',
#  'neg/cv149_17084.txt',
#  'neg/cv150_14279.txt',
#  'neg/cv151_17231.txt',
#  'neg/cv152_9052.txt',
#  'neg/cv153_11607.txt',
#  'neg/cv154_9562.txt',
#  'neg/cv155_7845.txt',
#  'neg/cv156_11119.txt',
#  'neg/cv157_29302.txt',
#  'neg/cv158_10914.txt',
#  'neg/cv159_29374.txt',
#  'neg/cv160_10848.txt',
#  'neg/cv161_12224.txt',
#  'neg/cv162_10977.txt',
#  'neg/cv163_10110.txt',
#  'neg/cv164_23451.txt',
#  'neg/cv165_2389.txt',
#  'neg/cv166_11959.txt',
#  'neg/cv167_18094.txt',
#  'neg/cv168_7435.txt',
#  'neg/cv169_24973.txt',
#  'neg/cv170_29808.txt',
#  'neg/cv171_15164.txt',
#  'neg/cv172_12037.txt',
#  'neg/cv173_4295.txt',
#  'neg/cv174_9735.txt',
#  'neg/cv175_7375.txt',
#  'neg/cv176_14196.txt',
#  'neg/cv177_10904.txt',
#  'neg/cv178_14380.txt',
#  'neg/cv179_9533.txt',
#  'neg/cv180_17823.txt',
#  'neg/cv181_16083.txt',
#  'neg/cv182_7791.txt',
#  'neg/cv183_19826.txt',
#  'neg/cv184_26935.txt',
#  'neg/cv185_28372.txt',
#  'neg/cv186_2396.txt',
#  'neg/cv187_14112.txt',
#  'neg/cv188_20687.txt',
#  'neg/cv189_24248.txt',
#  'neg/cv190_27176.txt',
#  'neg/cv191_29539.txt',
#  'neg/cv192_16079.txt',
#  'neg/cv193_5393.txt',
#  'neg/cv194_12855.txt',
#  'neg/cv195_16146.txt',
#  'neg/cv196_28898.txt',
#  'neg/cv197_29271.txt',
#  'neg/cv198_19313.txt',
#  'neg/cv199_9721.txt',
#  'neg/cv200_29006.txt',
#  'neg/cv201_7421.txt',
#  'neg/cv202_11382.txt',
#  'neg/cv203_19052.txt',
#  'neg/cv204_8930.txt',
#  'neg/cv205_9676.txt',
#  'neg/cv206_15893.txt',
#  'neg/cv207_29141.txt',
#  'neg/cv208_9475.txt',
#  'neg/cv209_28973.txt',
#  'neg/cv210_9557.txt',
#  'neg/cv211_9955.txt',
#  'neg/cv212_10054.txt',
#  'neg/cv213_20300.txt',
#  'neg/cv214_13285.txt',
#  'neg/cv215_23246.txt',
#  'neg/cv216_20165.txt',
#  'neg/cv217_28707.txt',
#  'neg/cv218_25651.txt',
#  'neg/cv219_19874.txt',
#  'neg/cv220_28906.txt',
#  'neg/cv221_27081.txt',
#  'neg/cv222_18720.txt',
#  'neg/cv223_28923.txt',
#  'neg/cv224_18875.txt',
#  'neg/cv225_29083.txt',
#  'neg/cv226_26692.txt',
#  'neg/cv227_25406.txt',
#  'neg/cv228_5644.txt',
#  'neg/cv229_15200.txt',
#  'neg/cv230_7913.txt',
#  'neg/cv231_11028.txt',
#  'neg/cv232_16768.txt',
#  'neg/cv233_17614.txt',
#  'neg/cv234_22123.txt',
#  'neg/cv235_10704.txt',
#  'neg/cv236_12427.txt',
#  'neg/cv237_20635.txt',
#  'neg/cv238_14285.txt',
#  'neg/cv239_29828.txt',
#  'neg/cv240_15948.txt',
#  'neg/cv241_24602.txt',
#  'neg/cv242_11354.txt',
#  'neg/cv243_22164.txt',
#  'neg/cv244_22935.txt',
#  'neg/cv245_8938.txt',
#  'neg/cv246_28668.txt',
#  'neg/cv247_14668.txt',
#  'neg/cv248_15672.txt',
#  'neg/cv249_12674.txt',
#  'neg/cv250_26462.txt',
#  'neg/cv251_23901.txt',
#  'neg/cv252_24974.txt',
#  'neg/cv253_10190.txt',
#  'neg/cv254_5870.txt',
#  'neg/cv255_15267.txt',
#  'neg/cv256_16529.txt',
#  'neg/cv257_11856.txt',
#  'neg/cv258_5627.txt',
#  'neg/cv259_11827.txt',
#  'neg/cv260_15652.txt',
#  'neg/cv261_11855.txt',
#  'neg/cv262_13812.txt',
#  'neg/cv263_20693.txt',
#  'neg/cv264_14108.txt',
#  'neg/cv265_11625.txt',
#  'neg/cv266_26644.txt',
#  'neg/cv267_16618.txt',
#  'neg/cv268_20288.txt',
#  'neg/cv269_23018.txt',
#  'neg/cv270_5873.txt',
#  'neg/cv271_15364.txt',
#  'neg/cv272_20313.txt',
#  'neg/cv273_28961.txt',
#  'neg/cv274_26379.txt',
#  'neg/cv275_28725.txt',
#  'neg/cv276_17126.txt',
#  'neg/cv277_20467.txt',
#  'neg/cv278_14533.txt',
#  'neg/cv279_19452.txt',
#  'neg/cv280_8651.txt',
#  'neg/cv281_24711.txt',
#  'neg/cv282_6833.txt',
#  'neg/cv283_11963.txt',
#  'neg/cv284_20530.txt',
#  'neg/cv285_18186.txt',
#  'neg/cv286_26156.txt',
#  'neg/cv287_17410.txt',
#  'neg/cv288_20212.txt',
#  'neg/cv289_6239.txt',
#  'neg/cv290_11981.txt',
#  'neg/cv291_26844.txt',
#  'neg/cv292_7804.txt',
#  'neg/cv293_29731.txt',
#  'neg/cv294_12695.txt',
#  'neg/cv295_17060.txt',
#  'neg/cv296_13146.txt',
#  'neg/cv297_10104.txt',
#  'neg/cv298_24487.txt',
#  'neg/cv299_17950.txt',
#  'neg/cv300_23302.txt',
#  'neg/cv301_13010.txt',
#  'neg/cv302_26481.txt',
#  'neg/cv303_27366.txt',
#  'neg/cv304_28489.txt',
#  'neg/cv305_9937.txt',
#  'neg/cv306_10859.txt',
#  'neg/cv307_26382.txt',
#  'neg/cv308_5079.txt',
#  'neg/cv309_23737.txt',
#  'neg/cv310_14568.txt',
#  'neg/cv311_17708.txt',
#  'neg/cv312_29308.txt',
#  'neg/cv313_19337.txt',
#  'neg/cv314_16095.txt',
#  'neg/cv315_12638.txt',
#  'neg/cv316_5972.txt',
#  'neg/cv317_25111.txt',
#  'neg/cv318_11146.txt',
#  'neg/cv319_16459.txt',
#  'neg/cv320_9693.txt',
#  'neg/cv321_14191.txt',
#  'neg/cv322_21820.txt',
#  'neg/cv323_29633.txt',
#  'neg/cv324_7502.txt',
#  'neg/cv325_18330.txt',
#  'neg/cv326_14777.txt',
#  'neg/cv327_21743.txt',
#  'neg/cv328_10908.txt',
#  'neg/cv329_29293.txt',
#  'neg/cv330_29675.txt',
#  'neg/cv331_8656.txt',
#  'neg/cv332_17997.txt',
#  'neg/cv333_9443.txt',
#  'neg/cv334_0074.txt',
#  'neg/cv335_16299.txt',
#  'neg/cv336_10363.txt',
#  'neg/cv337_29061.txt',
#  'neg/cv338_9183.txt',
#  'neg/cv339_22452.txt',
#  'neg/cv340_14776.txt',
#  'neg/cv341_25667.txt',
#  'neg/cv342_20917.txt',
#  'neg/cv343_10906.txt',
#  'neg/cv344_5376.txt',
#  'neg/cv345_9966.txt',
#  'neg/cv346_19198.txt',
#  'neg/cv347_14722.txt',
#  'neg/cv348_19207.txt',
#  'neg/cv349_15032.txt',
#  'neg/cv350_22139.txt',
#  'neg/cv351_17029.txt',
#  'neg/cv352_5414.txt',
#  'neg/cv353_19197.txt',
#  'neg/cv354_8573.txt',
#  'neg/cv355_18174.txt',
#  'neg/cv356_26170.txt',
#  'neg/cv357_14710.txt',
#  'neg/cv358_11557.txt',
#  'neg/cv359_6751.txt',
#  'neg/cv360_8927.txt',
#  'neg/cv361_28738.txt',
#  'neg/cv362_16985.txt',
#  'neg/cv363_29273.txt',
#  'neg/cv364_14254.txt',
#  'neg/cv365_12442.txt',
#  'neg/cv366_10709.txt',
#  'neg/cv367_24065.txt',
#  'neg/cv368_11090.txt',
#  'neg/cv369_14245.txt',
#  'neg/cv370_5338.txt',
#  'neg/cv371_8197.txt',
#  'neg/cv372_6654.txt',
#  'neg/cv373_21872.txt',
#  'neg/cv374_26455.txt',
#  'neg/cv375_9932.txt',
#  'neg/cv376_20883.txt',
#  'neg/cv377_8440.txt',
#  'neg/cv378_21982.txt',
#  'neg/cv379_23167.txt',
#  'neg/cv380_8164.txt',
#  'neg/cv381_21673.txt',
#  'neg/cv382_8393.txt',
#  'neg/cv383_14662.txt',
#  'neg/cv384_18536.txt',
#  'neg/cv385_29621.txt',
#  'neg/cv386_10229.txt',
#  'neg/cv387_12391.txt',
#  'neg/cv388_12810.txt',
#  'neg/cv389_9611.txt',
#  'neg/cv390_12187.txt',
#  'neg/cv391_11615.txt',
#  'neg/cv392_12238.txt',
#  'neg/cv393_29234.txt',
#  'neg/cv394_5311.txt',
#  'neg/cv395_11761.txt',
#  'neg/cv396_19127.txt',
#  'neg/cv397_28890.txt',
#  'neg/cv398_17047.txt',
#  'neg/cv399_28593.txt',
#  'neg/cv400_20631.txt',
#  'neg/cv401_13758.txt',
#  'neg/cv402_16097.txt',
#  'neg/cv403_6721.txt',
#  'neg/cv404_21805.txt',
#  'neg/cv405_21868.txt',
#  'neg/cv406_22199.txt',
#  'neg/cv407_23928.txt',
#  'neg/cv408_5367.txt',
#  'neg/cv409_29625.txt',
#  'neg/cv410_25624.txt',
#  'neg/cv411_16799.txt',
#  'neg/cv412_25254.txt',
#  'neg/cv413_7893.txt',
#  'neg/cv414_11161.txt',
#  'neg/cv415_23674.txt',
#  'neg/cv416_12048.txt',
#  'neg/cv417_14653.txt',
#  'neg/cv418_16562.txt',
#  'neg/cv419_14799.txt',
#  'neg/cv420_28631.txt',
#  'neg/cv421_9752.txt',
#  'neg/cv422_9632.txt',
#  'neg/cv423_12089.txt',
#  'neg/cv424_9268.txt',
#  'neg/cv425_8603.txt',
#  'neg/cv426_10976.txt',
#  'neg/cv427_11693.txt',
#  'neg/cv428_12202.txt',
#  'neg/cv429_7937.txt',
#  'neg/cv430_18662.txt',
#  'neg/cv431_7538.txt',
#  'neg/cv432_15873.txt',
#  'neg/cv433_10443.txt',
#  'neg/cv434_5641.txt',
#  'neg/cv435_24355.txt',
#  'neg/cv436_20564.txt',
#  'neg/cv437_24070.txt',
#  'neg/cv438_8500.txt',
#  'neg/cv439_17633.txt',
#  'neg/cv440_16891.txt',
#  'neg/cv441_15276.txt',
#  'neg/cv442_15499.txt',
#  'neg/cv443_22367.txt',
#  'neg/cv444_9975.txt',
#  'neg/cv445_26683.txt',
#  'neg/cv446_12209.txt',
#  'neg/cv447_27334.txt',
#  'neg/cv448_16409.txt',
#  'neg/cv449_9126.txt',
#  'neg/cv450_8319.txt',
#  'neg/cv451_11502.txt',
#  'neg/cv452_5179.txt',
#  'neg/cv453_10911.txt',
#  'neg/cv454_21961.txt',
#  'neg/cv455_28866.txt',
#  'neg/cv456_20370.txt',
#  'neg/cv457_19546.txt',
#  'neg/cv458_9000.txt',
#  'neg/cv459_21834.txt',
#  'neg/cv460_11723.txt',
#  'neg/cv461_21124.txt',
#  'neg/cv462_20788.txt',
#  'neg/cv463_10846.txt',
#  'neg/cv464_17076.txt',
#  'neg/cv465_23401.txt',
#  'neg/cv466_20092.txt',
#  'neg/cv467_26610.txt',
#  'neg/cv468_16844.txt',
#  'neg/cv469_21998.txt',
#  'neg/cv470_17444.txt',
#  'neg/cv471_18405.txt',
#  'neg/cv472_29140.txt',
#  'neg/cv473_7869.txt',
#  'neg/cv474_10682.txt',
#  'neg/cv475_22978.txt',
#  'neg/cv476_18402.txt',
#  'neg/cv477_23530.txt',
#  'neg/cv478_15921.txt',
#  'neg/cv479_5450.txt',
#  'neg/cv480_21195.txt',
#  'neg/cv481_7930.txt',
#  'neg/cv482_11233.txt',
#  'neg/cv483_18103.txt',
#  'neg/cv484_26169.txt',
#  'neg/cv485_26879.txt',
#  'neg/cv486_9788.txt',
#  'neg/cv487_11058.txt',
#  'neg/cv488_21453.txt',
#  'neg/cv489_19046.txt',
#  'neg/cv490_18986.txt',
#  'neg/cv491_12992.txt',
#  'neg/cv492_19370.txt',
#  'neg/cv493_14135.txt',
#  'neg/cv494_18689.txt',
#  'neg/cv495_16121.txt',
#  'neg/cv496_11185.txt',
#  'neg/cv497_27086.txt',
#  'neg/cv498_9288.txt',
#  'neg/cv499_11407.txt',
#  'neg/cv500_10722.txt',
#  'neg/cv501_12675.txt',
#  'neg/cv502_10970.txt',
#  'neg/cv503_11196.txt',
#  'neg/cv504_29120.txt',
#  'neg/cv505_12926.txt',
#  'neg/cv506_17521.txt',
#  'neg/cv507_9509.txt',
#  'neg/cv508_17742.txt',
#  'neg/cv509_17354.txt',
#  'neg/cv510_24758.txt',
#  'neg/cv511_10360.txt',
#  'neg/cv512_17618.txt',
#  'neg/cv513_7236.txt',
#  'neg/cv514_12173.txt',
#  'neg/cv515_18484.txt',
#  'neg/cv516_12117.txt',
#  'neg/cv517_20616.txt',
#  'neg/cv518_14798.txt',
#  'neg/cv519_16239.txt',
#  'neg/cv520_13297.txt',
#  'neg/cv521_1730.txt',
#  'neg/cv522_5418.txt',
#  'neg/cv523_18285.txt',
#  'neg/cv524_24885.txt',
#  'neg/cv525_17930.txt',
#  'neg/cv526_12868.txt',
#  'neg/cv527_10338.txt',
#  'neg/cv528_11669.txt',
#  'neg/cv529_10972.txt',
#  'neg/cv530_17949.txt',
#  'neg/cv531_26838.txt',
#  'neg/cv532_6495.txt',
#  'neg/cv533_9843.txt',
#  'neg/cv534_15683.txt',
#  'neg/cv535_21183.txt',
#  'neg/cv536_27221.txt',
#  'neg/cv537_13516.txt',
#  'neg/cv538_28485.txt',
#  'neg/cv539_21865.txt',
#  'neg/cv540_3092.txt',
#  'neg/cv541_28683.txt',
#  'neg/cv542_20359.txt',
#  'neg/cv543_5107.txt',
#  'neg/cv544_5301.txt',
#  'neg/cv545_12848.txt',
#  'neg/cv546_12723.txt',
#  'neg/cv547_18043.txt',
#  'neg/cv548_18944.txt',
#  'neg/cv549_22771.txt',
#  'neg/cv550_23226.txt',
#  'neg/cv551_11214.txt',
#  'neg/cv552_0150.txt',
#  'neg/cv553_26965.txt',
#  'neg/cv554_14678.txt',
#  'neg/cv555_25047.txt',
#  'neg/cv556_16563.txt',
#  'neg/cv557_12237.txt',
#  'neg/cv558_29376.txt',
#  'neg/cv559_0057.txt',
#  'neg/cv560_18608.txt',
#  'neg/cv561_9484.txt',
#  'neg/cv562_10847.txt',
#  'neg/cv563_18610.txt',
#  'neg/cv564_12011.txt',
#  'neg/cv565_29403.txt',
#  'neg/cv566_8967.txt',
#  'neg/cv567_29420.txt',
#  'neg/cv568_17065.txt',
#  'neg/cv569_26750.txt',
#  'neg/cv570_28960.txt',
#  'neg/cv571_29292.txt',
#  'neg/cv572_20053.txt',
#  'neg/cv573_29384.txt',
#  'neg/cv574_23191.txt',
#  'neg/cv575_22598.txt',
#  'neg/cv576_15688.txt',
#  'neg/cv577_28220.txt',
#  'neg/cv578_16825.txt',
#  'neg/cv579_12542.txt',
#  'neg/cv580_15681.txt',
#  'neg/cv581_20790.txt',
#  'neg/cv582_6678.txt',
#  'neg/cv583_29465.txt',
#  'neg/cv584_29549.txt',
#  'neg/cv585_23576.txt',
#  'neg/cv586_8048.txt',
#  'neg/cv587_20532.txt',
#  'neg/cv588_14467.txt',
#  'neg/cv589_12853.txt',
#  'neg/cv590_20712.txt',
#  'neg/cv591_24887.txt',
#  'neg/cv592_23391.txt',
#  'neg/cv593_11931.txt',
#  'neg/cv594_11945.txt',
#  'neg/cv595_26420.txt',
#  'neg/cv596_4367.txt',
#  'neg/cv597_26744.txt',
#  'neg/cv598_18184.txt',
#  'neg/cv599_22197.txt',
#  'neg/cv600_25043.txt',
#  'neg/cv601_24759.txt',
#  'neg/cv602_8830.txt',
#  'neg/cv603_18885.txt',
#  'neg/cv604_23339.txt',
#  'neg/cv605_12730.txt',
#  'neg/cv606_17672.txt',
#  'neg/cv607_8235.txt',
#  'neg/cv608_24647.txt',
#  'neg/cv609_25038.txt',
#  'neg/cv610_24153.txt',
#  'neg/cv611_2253.txt',
#  'neg/cv612_5396.txt',
#  'neg/cv613_23104.txt',
#  'neg/cv614_11320.txt',
#  'neg/cv615_15734.txt',
#  'neg/cv616_29187.txt',
#  'neg/cv617_9561.txt',
#  'neg/cv618_9469.txt',
#  'neg/cv619_13677.txt',
#  'neg/cv620_2556.txt',
#  'neg/cv621_15984.txt',
#  'neg/cv622_8583.txt',
#  'neg/cv623_16988.txt',
#  'neg/cv624_11601.txt',
#  'neg/cv625_13518.txt',
#  'neg/cv626_7907.txt',
#  'neg/cv627_12603.txt',
#  'neg/cv628_20758.txt',
#  'neg/cv629_16604.txt',
#  'neg/cv630_10152.txt',
#  'neg/cv631_4782.txt',
#  'neg/cv632_9704.txt',
#  'neg/cv633_29730.txt',
#  'neg/cv634_11989.txt',
#  'neg/cv635_0984.txt',
#  'neg/cv636_16954.txt',
#  'neg/cv637_13682.txt',
#  'neg/cv638_29394.txt',
#  'neg/cv639_10797.txt',
#  'neg/cv640_5380.txt',
#  'neg/cv641_13412.txt',
#  'neg/cv642_29788.txt',
#  'neg/cv643_29282.txt',
#  'neg/cv644_18551.txt',
#  'neg/cv645_17078.txt',
#  'neg/cv646_16817.txt',
#  'neg/cv647_15275.txt',
#  'neg/cv648_17277.txt',
#  'neg/cv649_13947.txt',
#  'neg/cv650_15974.txt',
#  'neg/cv651_11120.txt',
#  'neg/cv652_15653.txt',
#  'neg/cv653_2107.txt',
#  'neg/cv654_19345.txt',
#  'neg/cv655_12055.txt',
#  'neg/cv656_25395.txt',
#  'neg/cv657_25835.txt',
#  'neg/cv658_11186.txt',
#  'neg/cv659_21483.txt',
#  'neg/cv660_23140.txt',
#  'neg/cv661_25780.txt',
#  'neg/cv662_14791.txt',
#  'neg/cv663_14484.txt',
#  'neg/cv664_4264.txt',
#  'neg/cv665_29386.txt',
#  'neg/cv666_20301.txt',
#  'neg/cv667_19672.txt',
#  'neg/cv668_18848.txt',
#  'neg/cv669_24318.txt',
#  'neg/cv670_2666.txt',
#  'neg/cv671_5164.txt',
#  'neg/cv672_27988.txt',
#  'neg/cv673_25874.txt',
#  'neg/cv674_11593.txt',
#  'neg/cv675_22871.txt',
#  'neg/cv676_22202.txt',
#  'neg/cv677_18938.txt',
#  'neg/cv678_14887.txt',
#  'neg/cv679_28221.txt',
#  'neg/cv680_10533.txt',
#  'neg/cv681_9744.txt',
#  'neg/cv682_17947.txt',
#  'neg/cv683_13047.txt',
#  'neg/cv684_12727.txt',
#  'neg/cv685_5710.txt',
#  'neg/cv686_15553.txt',
#  'neg/cv687_22207.txt',
#  'neg/cv688_7884.txt',
#  'neg/cv689_13701.txt',
#  'neg/cv690_5425.txt',
#  'neg/cv691_5090.txt',
#  'neg/cv692_17026.txt',
#  'neg/cv693_19147.txt',
#  'neg/cv694_4526.txt',
#  'neg/cv695_22268.txt',
#  'neg/cv696_29619.txt',
#  'neg/cv697_12106.txt',
#  'neg/cv698_16930.txt',
#  'neg/cv699_7773.txt',
#  'neg/cv700_23163.txt',
#  'neg/cv701_15880.txt',
#  'neg/cv702_12371.txt',
#  'neg/cv703_17948.txt',
#  'neg/cv704_17622.txt',
#  'neg/cv705_11973.txt',
#  'neg/cv706_25883.txt',
#  'neg/cv707_11421.txt',
#  'neg/cv708_28539.txt',
#  'neg/cv709_11173.txt',
#  'neg/cv710_23745.txt',
#  'neg/cv711_12687.txt',
#  'neg/cv712_24217.txt',
#  'neg/cv713_29002.txt',
#  'neg/cv714_19704.txt',
#  'neg/cv715_19246.txt',
#  'neg/cv716_11153.txt',
#  'neg/cv717_17472.txt',
#  'neg/cv718_12227.txt',
#  'neg/cv719_5581.txt',
#  'neg/cv720_5383.txt',
#  'neg/cv721_28993.txt',
#  'neg/cv722_7571.txt',
#  'neg/cv723_9002.txt',
#  'neg/cv724_15265.txt',
#  'neg/cv725_10266.txt',
#  'neg/cv726_4365.txt',
#  'neg/cv727_5006.txt',
#  'neg/cv728_17931.txt',
#  'neg/cv729_10475.txt',
#  'neg/cv730_10729.txt',
#  'neg/cv731_3968.txt',
#  'neg/cv732_13092.txt',
#  'neg/cv733_9891.txt',
#  'neg/cv734_22821.txt',
#  'neg/cv735_20218.txt',
#  'neg/cv736_24947.txt',
#  'neg/cv737_28733.txt',
#  'neg/cv738_10287.txt',
#  'neg/cv739_12179.txt',
#  'neg/cv740_13643.txt',
#  'neg/cv741_12765.txt',
#  'neg/cv742_8279.txt',
#  'neg/cv743_17023.txt',
#  'neg/cv744_10091.txt',
#  'neg/cv745_14009.txt',
#  'neg/cv746_10471.txt',
#  'neg/cv747_18189.txt',
#  'neg/cv748_14044.txt',
#  'neg/cv749_18960.txt',
#  'neg/cv750_10606.txt',
#  'neg/cv751_17208.txt',
#  'neg/cv752_25330.txt',
#  'neg/cv753_11812.txt',
#  'neg/cv754_7709.txt',
#  'neg/cv755_24881.txt',
#  'neg/cv756_23676.txt',
#  'neg/cv757_10668.txt',
#  'neg/cv758_9740.txt',
#  'neg/cv759_15091.txt',
#  'neg/cv760_8977.txt',
#  'neg/cv761_13769.txt',
#  'neg/cv762_15604.txt',
#  'neg/cv763_16486.txt',
#  'neg/cv764_12701.txt',
#  'neg/cv765_20429.txt',
#  'neg/cv766_7983.txt',
#  'neg/cv767_15673.txt',
#  'neg/cv768_12709.txt',
#  'neg/cv769_8565.txt',
#  'neg/cv770_11061.txt',
#  'neg/cv771_28466.txt',
#  'neg/cv772_12971.txt',
#  'neg/cv773_20264.txt',
#  'neg/cv774_15488.txt',
#  'neg/cv775_17966.txt',
#  'neg/cv776_21934.txt',
#  'neg/cv777_10247.txt',
#  'neg/cv778_18629.txt',
#  'neg/cv779_18989.txt',
#  'neg/cv780_8467.txt',
#  'neg/cv781_5358.txt',
#  'neg/cv782_21078.txt',
#  'neg/cv783_14724.txt',
#  'neg/cv784_16077.txt',
#  'neg/cv785_23748.txt',
#  'neg/cv786_23608.txt',
#  'neg/cv787_15277.txt',
#  'neg/cv788_26409.txt',
#  'neg/cv789_12991.txt',
#  'neg/cv790_16202.txt',
#  'neg/cv791_17995.txt',
#  'neg/cv792_3257.txt',
#  'neg/cv793_15235.txt',
#  'neg/cv794_17353.txt',
#  'neg/cv795_10291.txt',
#  'neg/cv796_17243.txt',
#  'neg/cv797_7245.txt',
#  'neg/cv798_24779.txt',
#  'neg/cv799_19812.txt',
#  'neg/cv800_13494.txt',
#  'neg/cv801_26335.txt',
#  'neg/cv802_28381.txt',
#  'neg/cv803_8584.txt',
#  'neg/cv804_11763.txt',
#  'neg/cv805_21128.txt',
#  'neg/cv806_9405.txt',
#  'neg/cv807_23024.txt',
#  'neg/cv808_13773.txt',
#  'neg/cv809_5012.txt',
#  'neg/cv810_13660.txt',
#  'neg/cv811_22646.txt',
#  'neg/cv812_19051.txt',
#  'neg/cv813_6649.txt',
#  'neg/cv814_20316.txt',
#  'neg/cv815_23466.txt',
#  'neg/cv816_15257.txt',
#  'neg/cv817_3675.txt',
#  'neg/cv818_10698.txt',
#  'neg/cv819_9567.txt',
#  'neg/cv820_24157.txt',
#  'neg/cv821_29283.txt',
#  'neg/cv822_21545.txt',
#  'neg/cv823_17055.txt',
#  'neg/cv824_9335.txt',
#  'neg/cv825_5168.txt',
#  'neg/cv826_12761.txt',
#  'neg/cv827_19479.txt',
#  'neg/cv828_21392.txt',
#  'neg/cv829_21725.txt',
#  'neg/cv830_5778.txt',
#  'neg/cv831_16325.txt',
#  'neg/cv832_24713.txt',
#  'neg/cv833_11961.txt',
#  'neg/cv834_23192.txt',
#  'neg/cv835_20531.txt',
#  'neg/cv836_14311.txt',
#  'neg/cv837_27232.txt',
#  'neg/cv838_25886.txt',
#  'neg/cv839_22807.txt',
#  'neg/cv840_18033.txt',
#  'neg/cv841_3367.txt',
#  'neg/cv842_5702.txt',
#  'neg/cv843_17054.txt',
#  'neg/cv844_13890.txt',
#  'neg/cv845_15886.txt',
#  'neg/cv846_29359.txt',
#  'neg/cv847_20855.txt',
#  'neg/cv848_10061.txt',
#  'neg/cv849_17215.txt',
#  'neg/cv850_18185.txt',
#  'neg/cv851_21895.txt',
#  'neg/cv852_27512.txt',
#  'neg/cv853_29119.txt',
#  'neg/cv854_18955.txt',
#  'neg/cv855_22134.txt',
#  'neg/cv856_28882.txt',
#  'neg/cv857_17527.txt',
#  'neg/cv858_20266.txt',
#  'neg/cv859_15689.txt',
#  'neg/cv860_15520.txt',
#  'neg/cv861_12809.txt',
#  'neg/cv862_15924.txt',
#  'neg/cv863_7912.txt',
#  'neg/cv864_3087.txt',
#  'neg/cv865_28796.txt',
#  'neg/cv866_29447.txt',
#  'neg/cv867_18362.txt',
#  'neg/cv868_12799.txt',
#  'neg/cv869_24782.txt',
#  'neg/cv870_18090.txt',
#  'neg/cv871_25971.txt',
#  'neg/cv872_13710.txt',
#  'neg/cv873_19937.txt',
#  'neg/cv874_12182.txt',
#  'neg/cv875_5622.txt',
#  'neg/cv876_9633.txt',
#  'neg/cv877_29132.txt',
#  'neg/cv878_17204.txt',
#  'neg/cv879_16585.txt',
#  'neg/cv880_29629.txt',
#  'neg/cv881_14767.txt',
#  'neg/cv882_10042.txt',
#  'neg/cv883_27621.txt',
#  'neg/cv884_15230.txt',
#  'neg/cv885_13390.txt',
#  'neg/cv886_19210.txt',
#  'neg/cv887_5306.txt',
#  'neg/cv888_25678.txt',
#  'neg/cv889_22670.txt',
#  'neg/cv890_3515.txt',
#  'neg/cv891_6035.txt',
#  'neg/cv892_18788.txt',
#  'neg/cv893_26731.txt',
#  'neg/cv894_22140.txt',
#  'neg/cv895_22200.txt',
#  'neg/cv896_17819.txt',
#  'neg/cv897_11703.txt',
#  'neg/cv898_1576.txt',
#  'neg/cv899_17812.txt',
#  'neg/cv900_10800.txt',
#  'neg/cv901_11934.txt',
#  'neg/cv902_13217.txt',
#  'neg/cv903_18981.txt',
#  'neg/cv904_25663.txt',
#  'neg/cv905_28965.txt',
#  'neg/cv906_12332.txt',
#  'neg/cv907_3193.txt',
#  'neg/cv908_17779.txt',
#  'neg/cv909_9973.txt',
#  'neg/cv910_21930.txt',
#  'neg/cv911_21695.txt',
#  'neg/cv912_5562.txt',
#  'neg/cv913_29127.txt',
#  'neg/cv914_2856.txt',
#  'neg/cv915_9342.txt',
#  'neg/cv916_17034.txt',
#  'neg/cv917_29484.txt',
#  'neg/cv918_27080.txt',
#  'neg/cv919_18155.txt',
#  'neg/cv920_29423.txt',
#  'neg/cv921_13988.txt',
#  'neg/cv922_10185.txt',
#  'neg/cv923_11951.txt',
#  'neg/cv924_29397.txt',
#  'neg/cv925_9459.txt',
#  'neg/cv926_18471.txt',
#  'neg/cv927_11471.txt',
#  'neg/cv928_9478.txt',
#  'neg/cv929_1841.txt',
#  'neg/cv930_14949.txt',
#  'neg/cv931_18783.txt',
#  'neg/cv932_14854.txt',
#  'neg/cv933_24953.txt',
#  'neg/cv934_20426.txt',
#  'neg/cv935_24977.txt',
#  'neg/cv936_17473.txt',
#  'neg/cv937_9816.txt',
#  'neg/cv938_10706.txt',
#  'neg/cv939_11247.txt',
#  'neg/cv940_18935.txt',
#  'neg/cv941_10718.txt',
#  'neg/cv942_18509.txt',
#  'neg/cv943_23547.txt',
#  'neg/cv944_15042.txt',
#  'neg/cv945_13012.txt',
#  'neg/cv946_20084.txt',
#  'neg/cv947_11316.txt',
#  'neg/cv948_25870.txt',
#  'neg/cv949_21565.txt',
#  'neg/cv950_13478.txt',
#  'neg/cv951_11816.txt',
#  'neg/cv952_26375.txt',
#  'neg/cv953_7078.txt',
#  'neg/cv954_19932.txt',
#  'neg/cv955_26154.txt',
#  'neg/cv956_12547.txt',
#  'neg/cv957_9059.txt',
#  'neg/cv958_13020.txt',
#  'neg/cv959_16218.txt',
#  'neg/cv960_28877.txt',
#  'neg/cv961_5578.txt',
#  'neg/cv962_9813.txt',
#  'neg/cv963_7208.txt',
#  'neg/cv964_5794.txt',
#  'neg/cv965_26688.txt',
#  'neg/cv966_28671.txt',
#  'neg/cv967_5626.txt',
#  'neg/cv968_25413.txt',
#  'neg/cv969_14760.txt',
#  'neg/cv970_19532.txt',
#  'neg/cv971_11790.txt',
#  'neg/cv972_26837.txt',
#  'neg/cv973_10171.txt',
#  'neg/cv974_24303.txt',
#  'neg/cv975_11920.txt',
#  'neg/cv976_10724.txt',
#  'neg/cv977_4776.txt',
#  'neg/cv978_22192.txt',
#  'neg/cv979_2029.txt',
#  'neg/cv980_11851.txt',
#  'neg/cv981_16679.txt',
#  'neg/cv982_22209.txt',
#  'neg/cv983_24219.txt',
#  'neg/cv984_14006.txt',
#  'neg/cv985_5964.txt',
#  'neg/cv986_15092.txt',
#  'neg/cv987_7394.txt',
#  'neg/cv988_20168.txt',
#  'neg/cv989_17297.txt',
#  'neg/cv990_12443.txt',
#  'neg/cv991_19973.txt',
#  'neg/cv992_12806.txt',
#  'neg/cv993_29565.txt',
#  'neg/cv994_13229.txt',
#  'neg/cv995_23113.txt',
#  'neg/cv996_12447.txt',
#  'neg/cv997_5152.txt',
#  'neg/cv998_15691.txt',
#  'neg/cv999_14636.txt']

# %%
movie_reviews.words(movie_reviews.fileids()[5])
# Out:
# ['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...]

# %%
documents = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))
        
documents[0:4]
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg')]

# %%
import random

random.shuffle(documents)
documents[0:5]
# Out:
# [(['now', ',', 'lets', 'first', 'look', 'into', 'the', ...], 'pos'),
#  (['one', 'of', 'my', 'favorite', 'songs', 'by', 'the', ...], 'neg'),
#  (['lucas', 'was', 'wise', 'to', 'start', 'his', 'star', ...], 'neg'),
#  (['now', 'that', '"', 'boogie', 'nights', '"', 'has', ...], 'pos'),
#  (['in', '"', 'magic', 'town', '"', ',', 'jimmy', ...], 'pos')]

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet

def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk import pos_tag

w = "better"
pos_tag([w])
# Out:
# [('better', 'RBR')]

# %%
from nltk.corpus import stopwords
import string

stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
#   'hers',
#   'herself',
#   'him',
#   'himself',
#   'his',
#   'how',
#   'i',
#   'if',
#   'in',
#   'into',
#   'is',
#   'isn',
#   "isn't",
#   'it',
#   "it's",
#   'its',
#   'itself',
#   'just',
#   'll',
#   'm',
#   'ma',
#   'me',
#   'mightn',
#   "mightn't",
#   'more',
#   'most',
#   'mustn',
#   "mustn't",
#   'my',
#   'myself',
#   'needn',
#   "needn't",
#   'no',
#   'nor',
#   'not',
#   'now',
#   'o',
#   'of',
#   'off',
#   'on',
#   'once',
#   'only',
#   'or',
#   'other',
#   'our',
#   'ours',
#   'ourselves',
#   'out',
#   'over',
#   'own',
#   're',
#   's',
#   'same',
#   'shan',
#   "shan't",
#   'she',
#   "she's",
#   'should',
#   "should've",
#   'shouldn',
#   "shouldn't",
#   'so',
#   'some',
#   'such',
#   't',
#   'than',
#   'that',
#   "that'll",
#   'the',
#   'their',
#   'theirs',
#   'them',
#   'themselves',
#   'then',
#   'there',
#   'these',
#   'they',
#   'this',
#   'those',
#   'through',
#   'to',
#   'too',
#   'under',
#   'until',
#   'up',
#   've',
#   'very',
#   'was',
#   'wasn',
#   "wasn't",
#   'we',
#   'were',
#   'weren',
#   "weren't",
#   'what',
#   'when',
#   'where',
#   'which',
#   'while',
#   'who',
#   'whom',
#   'why',
#   'will',
#   'with',
#   'won',
#   "won't",
#   'wouldn',
#   "wouldn't",
#   'y',
#   'you',
#   "you'd",
#   "you'll",
#   "you're",
#   "you've",
#   'your',
#   'yours',
#   'yourself',
#   'yourselves',
#   '{',
#   '|',
#   '}',
#   '~'},
#  '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

# %%
def clean_review(words):
    
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
            
    return output_words

# %%
documents = [(clean_review(document), category) for document, category in documents]

# %%
documents[0]
# Out:
# (['let',
#   'first',
#   'look',
#   'history',
#   'shark',
#   'film',
#   'unforgettable',
#   'jaw',
#   'excite',
#   'jaw',
#   '2',
#   'rather',
#   'flaky',
#   'jaw',
#   '3d',
#   'sometime',
#   'late',
#   '90',
#   'another',
#   'film',
#   'genre',
#   'seem',
#   'recall',
#   'son',
#   'jaw',
#   'return',
#   'wreak',
#   'revenge',
#   'something',
#   'like',
#   'magic',
#   'cgi',
#   'one',
#   'shark',
#   'simply',
#   'enough',
#   'deep',
#   'blue',
#   'sea',
#   '3',
#   'big',
#   'mean',
#   'really',
#   'smart',
#   'one',
#   'russell',
#   'frankiln',
#   'jackson',
#   'visit',
#   'aquatica',
#   'sea',
#   'bound',
#   'research',
#   'center',
#   'research',
#   'conduct',
#   'extraction',
#   'hormone',
#   'substance',
#   'found',
#   'uniquely',
#   'within',
#   'shark',
#   'brain',
#   'cure',
#   'reverse',
#   'effect',
#   'alzheimer',
#   'disease',
#   'substance',
#   'small',
#   'quantity',
#   'lead',
#   'researcher',
#   'dr',
#   'susan',
#   'macalaester',
#   'genetically',
#   'alters',
#   'shark',
#   'dna',
#   'grows',
#   'twice',
#   'size',
#   'brain',
#   'big',
#   'human',
#   'naturally',
#   'produce',
#   'much',
#   'treasure',
#   'hormone',
#   'sure',
#   'sun',
#   'set',
#   'west',
#   'shark',
#   'break',
#   'lose',
#   'wreaks',
#   'havoc',
#   'within',
#   'facility',
#   'hormone',
#   'extraction',
#   'procedure',
#   'flexibility',
#   'offer',
#   'cgi',
#   'shark',
#   'get',
#   'full',
#   'length',
#   'screen',
#   'time',
#   'predecessor',
#   'remote',
#   'control',
#   'rubber',
#   'suit',
#   'day',
#   'go',
#   'day',
#   'people',
#   'get',
#   'pull',
#   'water',
#   'water',
#   'turn',
#   'red',
#   'right',
#   'time',
#   'get',
#   'see',
#   'entire',
#   'gobble',
#   'action',
#   'float',
#   'limb',
#   'act',
#   'expect',
#   'average',
#   'action',
#   'film',
#   'jackson',
#   'fresh',
#   'jedi',
#   'master',
#   'role',
#   'phantom',
#   'menace',
#   'take',
#   'dark',
#   'side',
#   'force',
#   'different',
#   'kind',
#   'fit',
#   'well',
#   'wise',
#   'crack',
#   'line',
#   'cool',
#   'j',
#   'cook',
#   'role',
#   'preacher',
#   'film',
#   'steven',
#   'seagal',
#   'cook',
#   'could',
#   'dream',
#   'achieve',
#   'two',
#   'siege',
#   'film',
#   'deep',
#   'blue',
#   'sea',
#   'offer',
#   'psychological',
#   'thrill',
#   'jaw',
#   'offer',
#   'however',
#   'prove',
#   'refresh',
#   'follow',
#   'within',
#   'genre',
#   'full',
#   'visual',
#   'thrill',
#   'suspense',
#   'believe',
#   '\x05',
#   'humour',
#   'like',
#   'jurassic',
#   'park',
#   'water',
#   'nothing',
#   'stressful',
#   'pure',
#   'entertainment',
#   'renny',
#   'harlin',
#   'forgiven',
#   'make',
#   'cutthroat',
#   'island'],
#  'pos')

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:]

# %%
a = [1, 2]
b = [3, 4]
a += b
a
# Out:
# [1, 2, 3, 4]

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %%
import nltk

# %%
freq = nltk.FreqDist(all_words)
common = freq.most_common(3000)
common
# Out:
# [('film', 8280),
#  ('movie', 5344),
#  ('one', 4485),
#  ('make', 3241),
#  ('like', 3052),
#  ('character', 2913),
#  ('get', 2755),
#  ('see', 2397),
#  ('go', 2268),
#  ('time', 2223),
#  ('well', 2162),
#  ('scene', 2025),
#  ('even', 1971),
#  ('good', 1820),
#  ('story', 1781),
#  ('take', 1686),
#  ('would', 1602),
#  ('much', 1542),
#  ('bad', 1488),
#  ('also', 1478),
#  ('come', 1468),
#  ('give', 1444),
#  ('look', 1434),
#  ('two', 1429),
#  ('way', 1420),
#  ('seem', 1403),
#  ('know', 1391),
#  ('life', 1368),
#  ('first', 1348),
#  ('end', 1307),
#  ('year', 1289),
#  ('--', 1287),
#  ('work', 1276),
#  ('thing', 1255),
#  ('say', 1229),
#  ('plot', 1222),
#  ('really', 1163),
#  ('show', 1141),
#  ('play', 1140),
#  ('little', 1137),
#  ('people', 1110),
#  ('star', 1090),
#  ('could', 1056),
#  ('man', 1053),
#  ('love', 1047),
#  ('try', 1023),
#  ('never', 1022),
#  ('director', 1020),
#  ('best', 1012),
#  ('new', 984),
#  ('great', 979),
#  ('many', 955),
#  ('actor', 951),
#  ('big', 948),
#  ('action', 942),
#  ('watch', 942),
#  ('want', 939),
#  ('performance', 933),
#  ('find', 917),
#  ('think', 892),
#  ('u', 891),
#  ('role', 854),
#  ('act', 853),
#  ('another', 828),
#  ('audience', 822),
#  ('back', 804),
#  ('still', 796),
#  ('something', 783),
#  ('turn', 778),
#  ('world', 764),
#  ('however', 751),
#  ('old', 748),
#  ('day', 745),
#  ('set', 743),
#  ('every', 714),
#  ('guy', 712),
#  ('though', 710),
#  ('use', 706),
#  ('comedy', 703),
#  ('cast', 701),
#  ('enough', 697),
#  ('feel', 694),
#  ('begin', 689),
#  ('interest', 670),
#  ('part', 668),
#  ('actually', 663),
#  ('young', 663),
#  ('name', 662),
#  ('last', 658),
#  ('real', 657),
#  ('point', 656),
#  ('around', 653),
#  ('run', 652),
#  ('script', 651),
#  ('funny', 646),
#  ('effect', 637),
#  ('fact', 636),
#  ('right', 634),
#  ('may', 634),
#  ('write', 632),
#  ('long', 631),
#  ('woman', 624),
#  ('lot', 624),
#  ('minute', 618),
#  ('friend', 618),
#  ('place', 604),
#  ('almost', 601),
#  ('john', 600),
#  ('screen', 599),
#  ('nothing', 599),
#  ('line', 598),
#  ('moment', 577),
#  ('since', 572),
#  ('become', 570),
#  ('call', 569),
#  ('played', 569),
#  ('ever', 568),
#  ('tell', 566),
#  ('start', 563),
#  ('although', 557),
#  ('family', 547),
#  ('help', 544),
#  ('kill', 537),
#  ('original', 526),
#  ('without', 525),
#  ('problem', 524),
#  ('three', 522),
#  ('lead', 521),
#  ('picture', 521),
#  ('least', 513),
#  ('high', 507),
#  ('laugh', 505),
#  ('girl', 505),
#  ('sequence', 500),
#  ('need', 497),
#  ('might', 486),
#  ('away', 478),
#  ('fall', 477),
#  ('far', 475),
#  ('quite', 474),
#  ('put', 472),
#  ('course', 472),
#  ('american', 467),
#  ('keep', 465),
#  ('child', 464),
#  ('bit', 463),
#  ('rather', 461),
#  ('attempt', 457),
#  ('alien', 457),
#  ('include', 454),
#  ('always', 453),
#  ('kind', 450),
#  ('job', 450),
#  ('must', 446),
#  ('follow', 442),
#  ('special', 442),
#  ('anything', 442),
#  ('war', 441),
#  ('hour', 439),
#  ('yet', 438),
#  ('hard', 437),
#  ('wife', 435),
#  ('fun', 433),
#  ('feature', 430),
#  ('black', 429),
#  ('home', 428),
#  ('reason', 428),
#  ('instead', 423),
#  ('hand', 423),
#  ('head', 422),
#  ('hollywood', 419),
#  ('sense', 419),
#  ('lose', 417),
#  ('probably', 413),
#  ('men', 411),
#  ('kid', 409),
#  ('human', 408),
#  ('half', 408),
#  ('shot', 407),
#  ('mind', 405),
#  ('series', 404),
#  ('idea', 403),
#  ('move', 403),
#  ('pretty', 401),
#  ('involve', 401),
#  ('face', 399),
#  ('night', 399),
#  ('let', 395),
#  ('along', 395),
#  ('dialogue', 395),
#  ('direct', 390),
#  ('talk', 390),
#  ('everything', 387),
#  ('together', 384),
#  ('force', 383),
#  ('sure', 382),
#  ('believe', 382),
#  ('whole', 380),
#  ('money', 379),
#  ('sex', 375),
#  ('second', 375),
#  ('music', 375),
#  ('release', 372),
#  ('question', 368),
#  ('horror', 368),
#  ('becomes', 366),
#  ('father', 366),
#  ('save', 366),
#  ('thought', 365),
#  ('everyone', 361),
#  ('fight', 360),
#  ('appear', 358),
#  ('mother', 357),
#  ('city', 357),
#  ('boy', 353),
#  ('death', 351),
#  ('do', 351),
#  ('evil', 350),
#  ('next', 350),
#  ('especially', 348),
#  ('small', 347),
#  ('perhaps', 347),
#  ('eye', 343),
#  ('happen', 343),
#  ('brother', 343),
#  ('base', 341),
#  ('relationship', 341),
#  ('expect', 340),
#  ('couple', 337),
#  ('less', 337),
#  ('case', 336),
#  ('writer', 334),
#  ('different', 333),
#  ('meet', 333),
#  ('rest', 332),
#  ('change', 332),
#  ('mean', 331),
#  ('joke', 330),
#  ('sound', 330),
#  ('review', 328),
#  ('2', 327),
#  ('10', 326),
#  ('whose', 325),
#  ('late', 324),
#  ('completely', 324),
#  ('care', 323),
#  ('create', 322),
#  ('fan', 322),
#  ('book', 321),
#  ('several', 321),
#  ('comic', 321),
#  ('michael', 320),
#  ('anyone', 319),
#  ('word', 316),
#  ('school', 316),
#  ('live', 315),
#  ('hit', 314),
#  ('suppose', 313),
#  ('left', 313),
#  ('add', 312),
#  ('true', 311),
#  ('simply', 309),
#  ('game', 309),
#  ('main', 309),
#  ('entertain', 309),
#  ('top', 308),
#  ('humor', 308),
#  ('someone', 307),
#  ('lack', 306),
#  ('mr', 303),
#  ('car', 303),
#  ('matter', 302),
#  ('tv', 301),
#  ('leave', 300),
#  ('found', 299),
#  ('house', 296),
#  ('either', 296),
#  ('james', 295),
#  ('wrong', 294),
#  ('side', 293),
#  ('often', 293),
#  ('support', 292),
#  ('town', 290),
#  ('viewer', 290),
#  ('group', 289),
#  ('wonder', 288),
#  ('david', 288),
#  ('else', 287),
#  ('power', 286),
#  ('enjoy', 286),
#  ('hero', 285),
#  ('full', 282),
#  ('deal', 282),
#  ('robert', 282),
#  ('present', 282),
#  ('later', 281),
#  ('result', 281),
#  ('credit', 280),
#  ('behind', 278),
#  ('final', 277),
#  ('soon', 277),
#  ('dead', 276),
#  ('camera', 276),
#  ('scream', 276),
#  ('open', 275),
#  ('unfortunately', 275),
#  ('provide', 274),
#  ('murder', 274),
#  ('able', 273),
#  ('son', 271),
#  ('style', 271),
#  ('summer', 270),
#  ('element', 269),
#  ('despite', 268),
#  ('entire', 267),
#  ('nice', 267),
#  ('team', 267),
#  ('theater', 267),
#  ('return', 266),
#  ('stop', 265),
#  ('finally', 265),
#  ('maybe', 265),
#  ('die', 265),
#  ('order', 263),
#  ('person', 260),
#  ('past', 260),
#  ('miss', 260),
#  ('situation', 259),
#  ('title', 258),
#  ('view', 258),
#  ('example', 255),
#  ('perfect', 255),
#  ('cop', 255),
#  ('certainly', 255),
#  ('sort', 254),
#  ('joe', 252),
#  ('fine', 251),
#  ('version', 249),
#  ('stand', 249),
#  ('worth', 249),
#  ('note', 248),
#  ('piece', 248),
#  ('classic', 248),
#  ('cut', 247),
#  ('hope', 246),
#  ('video', 245),
#  ('consider', 243),
#  ('bring', 242),
#  ('drama', 241),
#  ('self', 240),
#  ('major', 240),
#  ('voice', 240),
#  ('early', 239),
#  ('white', 239),
#  ('beautiful', 238),
#  ('strong', 238),
#  ('production', 237),
#  ('body', 237),
#  ('event', 236),
#  ('upon', 234),
#  ('five', 234),
#  ('violence', 234),
#  ('heart', 234),
#  ('break', 233),
#  ('talent', 233),
#  ('killer', 233),
#  ('screenplay', 233),
#  ('daughter', 232),
#  ('nearly', 232),
#  ('short', 232),
#  ('close', 232),
#  ('wait', 230),
#  ('already', 229),
#  ('level', 229),
#  ('pull', 228),
#  ('ship', 228),
#  ('dark', 227),
#  ('room', 227),
#  ('four', 227),
#  ('deep', 226),
#  ('opening', 226),
#  ('thriller', 224),
#  ('light', 224),
#  ('age', 223),
#  ('obvious', 223),
#  ('dog', 223),
#  ('ask', 223),
#  ('disney', 222),
#  ('king', 222),
#  ('experience', 222),
#  ('chase', 222),
#  ('earth', 221),
#  ('learn', 220),
#  ('offer', 219),
#  ('guess', 219),
#  ('state', 218),
#  ('surprise', 217),
#  ('waste', 216),
#  ('throughout', 216),
#  ('figure', 216),
#  ('number', 215),
#  ('exactly', 215),
#  ('kevin', 215),
#  ('jack', 214),
#  ('others', 214),
#  ('1', 213),
#  ('hold', 213),
#  ('form', 212),
#  ('flick', 212),
#  ('plan', 212),
#  ('direction', 210),
#  ('romantic', 210),
#  ('twist', 210),
#  ('pace', 209),
#  ('art', 208),
#  ('realize', 208),
#  ('easy', 208),
#  ('computer', 207),
#  ('sometimes', 207),
#  ('career', 207),
#  ('dream', 206),
#  ('simple', 206),
#  ('fill', 206),
#  ('type', 205),
#  ('walk', 205),
#  ('filmmaker', 204),
#  ('touch', 204),
#  ('novel', 203),
#  ('gun', 202),
#  ('jackie', 202),
#  ('charm', 201),
#  ('planet', 201),
#  ('win', 201),
#  ('husband', 200),
#  ('rise', 199),
#  ('score', 199),
#  ('boring', 197),
#  ('tom', 197),
#  ('space', 197),
#  ('member', 197),
#  ('saw', 196),
#  ('carry', 196),
#  ('paul', 196),
#  ('truly', 195),
#  ('york', 195),
#  ('tale', 195),
#  ('oscar', 195),
#  ('drug', 193),
#  ('possible', 192),
#  ('battle', 192),
#  ('hell', 192),
#  ('peter', 192),
#  ('sequel', 192),
#  ('song', 191),
#  ('material', 191),
#  ('focus', 191),
#  ('wild', 190),
#  ('remember', 189),
#  ('3', 188),
#  ('decide', 188),
#  ('chance', 188),
#  ('extremely', 188),
#  ('rock', 188),
#  ('genre', 187),
#  ('smith', 187),
#  ('god', 187),
#  ('particularly', 186),
#  ('police', 186),
#  ('quickly', 185),
#  ('de', 185),
#  ('manages', 185),
#  ('attention', 185),
#  ('parent', 185),
#  ('stupid', 185),
#  ('happens', 184),
#  ('lee', 184),
#  ('shoot', 183),
#  ('escape', 183),
#  ('pay', 182),
#  ('usually', 182),
#  ('stay', 181),
#  ('none', 181),
#  ('mostly', 181),
#  ('fiction', 181),
#  ('villain', 181),
#  ('studio', 181),
#  ('yes', 181),
#  ('success', 180),
#  ('girlfriend', 180),
#  ('dr', 179),
#  ('flaw', 179),
#  ('cover', 179),
#  ('quality', 179),
#  ('image', 179),
#  ('detail', 178),
#  ('single', 178),
#  ('project', 178),
#  ('television', 178),
#  ('million', 177),
#  ('large', 176),
#  ('eventually', 176),
#  ('slow', 176),
#  ('co', 176),
#  ('except', 175),
#  ('middle', 175),
#  ('steal', 174),
#  ('mention', 174),
#  ('sit', 173),
#  ('low', 173),
#  ('across', 172),
#  ('van', 172),
#  ('law', 172),
#  ('theme', 172),
#  ('alone', 171),
#  ('crime', 171),
#  ('read', 171),
#  ('actress', 171),
#  ('attack', 171),
#  ('future', 170),
#  ('obviously', 170),
#  ('told', 170),
#  ('secret', 169),
#  ('oh', 169),
#  ('within', 168),
#  ('premise', 168),
#  ('water', 167),
#  ('williams', 167),
#  ('understand', 166),
#  ('complete', 166),
#  ('drive', 166),
#  ('impressive', 165),
#  ('recent', 165),
#  ('explain', 165),
#  ('mystery', 165),
#  ('emotional', 164),
#  ('batman', 164),
#  ('robin', 164),
#  ('amaze', 164),
#  ('history', 163),
#  ('science', 163),
#  ('cause', 163),
#  ('company', 162),
#  ('poor', 162),
#  ('living', 162),
#  ('wonderful', 162),
#  ('easily', 162),
#  ('somehow', 160),
#  ('country', 160),
#  ('important', 159),
#  ('effort', 159),
#  ('wish', 159),
#  ('aspect', 159),
#  ('office', 159),
#  ('harry', 159),
#  ('cool', 158),
#  ('4', 158),
#  ('street', 158),
#  ('ryan', 158),
#  ('control', 157),
#  ('among', 157),
#  ('motion', 157),
#  ('agent', 157),
#  ('whether', 156),
#  ('local', 156),
#  ('america', 156),
#  ('lie', 155),
#  ('fire', 155),
#  ('message', 155),
#  ('chris', 155),
#  ('mark', 155),
#  ('wedding', 154),
#  ('subject', 154),
#  ('fear', 154),
#  ('difficult', 154),
#  ('cross', 154),
#  ('jones', 154),
#  ('rich', 153),
#  ('serious', 153),
#  ('doubt', 153),
#  ('murphy', 153),
#  ('fast', 153),
#  ('entertainment', 152),
#  ('fail', 152),
#  ('happy', 152),
#  ('screenwriter', 152),
#  ('ben', 152),
#  ('near', 151),
#  ('third', 151),
#  ('critic', 151),
#  ('brings', 150),
#  ('class', 150),
#  ('reality', 150),
#  ('hilarious', 150),
#  ('dramatic', 150),
#  ('george', 150),
#  ('stuff', 149),
#  ('throw', 149),
#  ('basically', 149),
#  ('surprisingly', 149),
#  ('due', 149),
#  ('fly', 149),
#  ('produce', 148),
#  ('suspense', 148),
#  ('annoy', 148),
#  ('us', 148),
#  ('trouble', 148),
#  ('certain', 148),
#  ('william', 148),
#  ('ago', 147),
#  ('speak', 147),
#  ('answer', 147),
#  ('apparently', 147),
#  ('sexual', 147),
#  ('previous', 146),
#  ('bill', 146),
#  ('crew', 146),
#  ('similar', 146),
#  ('vampire', 146),
#  ('jim', 146),
#  ('budget', 146),
#  ('intelligent', 145),
#  ('emotion', 145),
#  ('general', 145),
#  ('smart', 144),
#  ('presence', 144),
#  ('blood', 144),
#  ('choice', 144),
#  ('business', 144),
#  ('appeal', 143),
#  ('personal', 143),
#  ('confuse', 143),
#  ('bob', 143),
#  ('visual', 142),
#  ('predictable', 142),
#  ('clear', 142),
#  ('party', 142),
#  ('decides', 142),
#  ('mission', 142),
#  ('producer', 142),
#  ('tone', 141),
#  ('wear', 141),
#  ('clever', 141),
#  ('approach', 141),
#  ('teen', 141),
#  ('scary', 141),
#  ('somewhat', 141),
#  ('beyond', 141),
#  ('romance', 141),
#  ('leaf', 140),
#  ('familiar', 140),
#  ('deliver', 140),
#  ('la', 140),
#  ('excellent', 140),
#  ('rat', 140),
#  ('sister', 140),
#  ('red', 139),
#  ('prison', 139),
#  ('favorite', 138),
#  ('date', 138),
#  ('ability', 138),
#  ('share', 138),
#  ('absolutely', 138),
#  ('excite', 137),
#  ('r', 137),
#  ('adult', 137),
#  ('successful', 137),
#  ('cinema', 137),
#  ('b', 137),
#  ('catch', 136),
#  ('giant', 136),
#  ('treat', 135),
#  ('frank', 135),
#  ('allow', 135),
#  ('mess', 135),
#  ('popular', 135),
#  ('discover', 135),
#  ('rule', 134),
#  ('anyway', 134),
#  ('box', 134),
#  ('potential', 134),
#  ('strike', 134),
#  ('trek', 134),
#  ('strange', 133),
#  ('effective', 132),
#  ('definitely', 132),
#  ('student', 132),
#  ('private', 132),
#  ('amount', 132),
#  ('nature', 132),
#  ('trailer', 132),
#  ('eddie', 132),
#  ('felt', 131),
#  ('immediately', 131),
#  ('shock', 131),
#  ('powerful', 131),
#  ('truman', 131),
#  ('victim', 131),
#  ('fails', 130),
#  ('thrill', 129),
#  ('hate', 129),
#  ('handle', 129),
#  ('free', 129),
#  ('continue', 129),
#  ('former', 129),
#  ('master', 128),
#  ('usual', 128),
#  ('seriously', 128),
#  ('appearance', 128),
#  ('track', 128),
#  ('martin', 128),
#  ('scott', 128),
#  ('pick', 128),
#  ('search', 128),
#  ('development', 128),
#  ('capture', 128),
#  ('blue', 127),
#  ('join', 127),
#  ('rating', 127),
#  ('neither', 127),
#  ('stone', 127),
#  ('week', 127),
#  ('sam', 127),
#  ('manage', 126),
#  ('huge', 126),
#  ('truth', 126),
#  ('convincing', 126),
#  ('grace', 126),
#  ('issue', 125),
#  ('straight', 125),
#  ('race', 125),
#  ('inside', 125),
#  ('solid', 125),
#  ('musical', 125),
#  ('unlike', 125),
#  ('perfectly', 125),
#  ('sweet', 125),
#  ('sign', 124),
#  ('enjoyable', 124),
#  ('animate', 124),
#  ('hunt', 124),
#  ('door', 124),
#  ('kiss', 124),
#  ('ape', 124),
#  ('purpose', 123),
#  ('serve', 123),
#  ('air', 123),
#  ('spend', 123),
#  ('reveal', 123),
#  ('haunt', 123),
#  ('cameron', 123),
#  ('otherwise', 123),
#  ('married', 123),
#  ('land', 123),
#  ('prove', 122),
#  ('gag', 122),
#  ('non', 122),
#  ('toy', 122),
#  ('suspect', 122),
#  ('decent', 122),
#  ('political', 122),
#  ('dance', 122),
#  ('grow', 122),
#  ('ex', 121),
#  ('sight', 121),
#  ('overall', 121),
#  ('front', 121),
#  ('merely', 121),
#  ('travel', 121),
#  ('likely', 121),
#  ('army', 121),
#  ('animation', 121),
#  ('drop', 121),
#  ('nick', 121),
#  ('west', 120),
#  ('imagine', 120),
#  ('depth', 120),
#  ('bunch', 120),
#  ('park', 119),
#  ('l', 119),
#  ('ten', 119),
#  ('reach', 119),
#  ('female', 119),
#  ('heard', 119),
#  ('government', 119),
#  ('require', 119),
#  ('society', 119),
#  ('bruce', 119),
#  ('baby', 119),
#  ('train', 119),
#  ('arm', 118),
#  ('e', 118),
#  ('pop', 118),
#  ('sell', 118),
#  ('respect', 117),
#  ('english', 117),
#  ('particular', 117),
#  ('towards', 117),
#  ('design', 117),
#  ('lover', 117),
#  ('background', 117),
#  ('fashion', 117),
#  ('adventure', 117),
#  ('richard', 117),
#  ('brilliant', 116),
#  ('actual', 116),
#  ('term', 116),
#  ('monster', 116),
#  ('struggle', 116),
#  ('silly', 116),
#  ('chan', 116),
#  ('ground', 116),
#  ('steve', 116),
#  ('various', 116),
#  ('spirit', 115),
#  ('succeed', 115),
#  ('award', 115),
#  ('modern', 115),
#  ('player', 115),
#  ('menace', 114),
#  ('queen', 114),
#  ('club', 114),
#  ('cold', 114),
#  ('talented', 114),
#  ('step', 114),
#  ('impact', 114),
#  ('8', 114),
#  ('memorable', 114),
#  ('impossible', 114),
#  ('raise', 114),
#  ('rush', 114),
#  ('steven', 113),
#  ('tension', 113),
#  ('amuse', 113),
#  ('titanic', 113),
#  ('mouth', 112),
#  ('suddenly', 112),
#  ('tim', 112),
#  ('double', 112),
#  ('mar', 112),
#  ('list', 111),
#  ('today', 111),
#  ('subtle', 111),
#  ('brought', 111),
#  ('hear', 111),
#  ('road', 111),
#  ('doctor', 111),
#  ('hop', 111),
#  ('suffer', 110),
#  ('carter', 110),
#  ('cannot', 110),
#  ('5', 110),
#  ('dollar', 110),
#  ('episode', 109),
#  ('month', 109),
#  ('terrible', 109),
#  ('detective', 109),
#  ('building', 109),
#  ('willis', 109),
#  ('compare', 109),
#  ('engage', 109),
#  ('ultimately', 109),
#  ('opportunity', 108),
#  ('entirely', 108),
#  ('key', 108),
#  ('roll', 108),
#  ('spielberg', 108),
#  ('promise', 108),
#  ('dumb', 107),
#  ('costume', 107),
#  ('color', 107),
#  ('disaster', 107),
#  ('ghost', 107),
#  ('cliche', 107),
#  ('soundtrack', 107),
#  ('officer', 107),
#  ('90', 106),
#  ('store', 106),
#  ('personality', 106),
#  ('slightly', 106),
#  ('fairly', 106),
#  ('hot', 106),
#  ('soldier', 106),
#  ('leader', 106),
#  ('male', 106),
#  ('pair', 105),
#  ('lawyer', 105),
#  ('sent', 105),
#  ('spent', 105),
#  ('complex', 105),
#  ('machine', 105),
#  ('awful', 105),
#  ('max', 105),
#  ('totally', 105),
#  ('rescue', 105),
#  ('recommend', 105),
#  ('angel', 105),
#  ('allen', 105),
#  ('woody', 105),
#  ('godzilla', 105),
#  ('ii', 105),
#  ('thin', 104),
#  ('delivers', 104),
#  ('beauty', 104),
#  ('climax', 104),
#  ('highly', 104),
#  ('partner', 104),
#  ('bug', 104),
#  ('minor', 104),
#  ('atmosphere', 104),
#  ('hill', 104),
#  ('vega', 104),
#  ('mike', 104),
#  ('trip', 104),
#  ('ridiculous', 104),
#  ('simon', 104),
#  ('longer', 103),
#  ('grant', 103),
#  ('adam', 103),
#  ('seven', 103),
#  ('basic', 103),
#  ('animal', 103),
#  ('camp', 103),
#  ('admit', 103),
#  ('cheap', 102),
#  ('six', 102),
#  ('outside', 102),
#  ('introduce', 102),
#  ('plenty', 102),
#  ('recently', 102),
#  ('x', 102),
#  ('realistic', 102),
#  ('hole', 102),
#  ('foot', 102),
#  ('twenty', 102),
#  ('jackson', 101),
#  ('clearly', 101),
#  ('sean', 101),
#  ('president', 101),
#  ('indeed', 101),
#  ('typical', 101),
#  ('sci', 101),
#  ('fi', 101),
#  ('british', 101),
#  ('flat', 101),
#  ('spot', 101),
#  ('period', 101),
#  ('dress', 101),
#  ('edit', 101),
#  ('julia', 101),
#  ('fit', 100),
#  ('whatever', 100),
#  ('edward', 100),
#  ('kick', 100),
#  ('lucas', 100),
#  ('standard', 100),
#  ('damn', 100),
#  ('earlier', 100),
#  ('cameo', 100),
#  ('concept', 100),
#  ('creature', 100),
#  ('quick', 100),
#  ('brain', 99),
#  ('buddy', 99),
#  ('constantly', 99),
#  ('frame', 99),
#  ('conclusion', 99),
#  ('cage', 99),
#  ('hire', 99),
#  ('jerry', 99),
#  ('brief', 99),
#  ('bore', 98),
#  ('heavy', 98),
#  ('college', 98),
#  ('teacher', 98),
#  ('energy', 98),
#  ('medium', 98),
#  ('tough', 98),
#  ('ride', 98),
#  ('wall', 98),
#  ('target', 98),
#  ('singer', 98),
#  ('island', 97),
#  ('intelligence', 97),
#  ('cute', 97),
#  ('lame', 97),
#  ('century', 97),
#  ('inspire', 97),
#  ('green', 97),
#  ('sing', 96),
#  ('dull', 96),
#  ('believable', 96),
#  ('violent', 96),
#  ('cinematography', 96),
#  ('aside', 96),
#  ('thanks', 96),
#  ('common', 96),
#  ('french', 96),
#  ('1998', 96),
#  ('appreciate', 96),
#  ('loud', 95),
#  ...]

# %%
features = [i[0] for i in common]
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'like',
#  'character',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'much',
#  'bad',
#  'also',
#  'come',
#  'give',
#  'look',
#  'two',
#  'way',
#  'seem',
#  'know',
#  'life',
#  'first',
#  'end',
#  'year',
#  '--',
#  'work',
#  'thing',
#  'say',
#  'plot',
#  'really',
#  'show',
#  'play',
#  'little',
#  'people',
#  'star',
#  'could',
#  'man',
#  'love',
#  'try',
#  'never',
#  'director',
#  'best',
#  'new',
#  'great',
#  'many',
#  'actor',
#  'big',
#  'action',
#  'watch',
#  'want',
#  'performance',
#  'find',
#  'think',
#  'u',
#  'role',
#  'act',
#  'another',
#  'audience',
#  'back',
#  'still',
#  'something',
#  'turn',
#  'world',
#  'however',
#  'old',
#  'day',
#  'set',
#  'every',
#  'guy',
#  'though',
#  'use',
#  'comedy',
#  'cast',
#  'enough',
#  'feel',
#  'begin',
#  'interest',
#  'part',
#  'actually',
#  'young',
#  'name',
#  'last',
#  'real',
#  'point',
#  'around',
#  'run',
#  'script',
#  'funny',
#  'effect',
#  'fact',
#  'right',
#  'may',
#  'write',
#  'long',
#  'woman',
#  'lot',
#  'minute',
#  'friend',
#  'place',
#  'almost',
#  'john',
#  'screen',
#  'nothing',
#  'line',
#  'moment',
#  'since',
#  'become',
#  'call',
#  'played',
#  'ever',
#  'tell',
#  'start',
#  'although',
#  'family',
#  'help',
#  'kill',
#  'original',
#  'without',
#  'problem',
#  'three',
#  'lead',
#  'picture',
#  'least',
#  'high',
#  'laugh',
#  'girl',
#  'sequence',
#  'need',
#  'might',
#  'away',
#  'fall',
#  'far',
#  'quite',
#  'put',
#  'course',
#  'american',
#  'keep',
#  'child',
#  'bit',
#  'rather',
#  'attempt',
#  'alien',
#  'include',
#  'always',
#  'kind',
#  'job',
#  'must',
#  'follow',
#  'special',
#  'anything',
#  'war',
#  'hour',
#  'yet',
#  'hard',
#  'wife',
#  'fun',
#  'feature',
#  'black',
#  'home',
#  'reason',
#  'instead',
#  'hand',
#  'head',
#  'hollywood',
#  'sense',
#  'lose',
#  'probably',
#  'men',
#  'kid',
#  'human',
#  'half',
#  'shot',
#  'mind',
#  'series',
#  'idea',
#  'move',
#  'pretty',
#  'involve',
#  'face',
#  'night',
#  'let',
#  'along',
#  'dialogue',
#  'direct',
#  'talk',
#  'everything',
#  'together',
#  'force',
#  'sure',
#  'believe',
#  'whole',
#  'money',
#  'sex',
#  'second',
#  'music',
#  'release',
#  'question',
#  'horror',
#  'becomes',
#  'father',
#  'save',
#  'thought',
#  'everyone',
#  'fight',
#  'appear',
#  'mother',
#  'city',
#  'boy',
#  'death',
#  'do',
#  'evil',
#  'next',
#  'especially',
#  'small',
#  'perhaps',
#  'eye',
#  'happen',
#  'brother',
#  'base',
#  'relationship',
#  'expect',
#  'couple',
#  'less',
#  'case',
#  'writer',
#  'different',
#  'meet',
#  'rest',
#  'change',
#  'mean',
#  'joke',
#  'sound',
#  'review',
#  '2',
#  '10',
#  'whose',
#  'late',
#  'completely',
#  'care',
#  'create',
#  'fan',
#  'book',
#  'several',
#  'comic',
#  'michael',
#  'anyone',
#  'word',
#  'school',
#  'live',
#  'hit',
#  'suppose',
#  'left',
#  'add',
#  'true',
#  'simply',
#  'game',
#  'main',
#  'entertain',
#  'top',
#  'humor',
#  'someone',
#  'lack',
#  'mr',
#  'car',
#  'matter',
#  'tv',
#  'leave',
#  'found',
#  'house',
#  'either',
#  'james',
#  'wrong',
#  'side',
#  'often',
#  'support',
#  'town',
#  'viewer',
#  'group',
#  'wonder',
#  'david',
#  'else',
#  'power',
#  'enjoy',
#  'hero',
#  'full',
#  'deal',
#  'robert',
#  'present',
#  'later',
#  'result',
#  'credit',
#  'behind',
#  'final',
#  'soon',
#  'dead',
#  'camera',
#  'scream',
#  'open',
#  'unfortunately',
#  'provide',
#  'murder',
#  'able',
#  'son',
#  'style',
#  'summer',
#  'element',
#  'despite',
#  'entire',
#  'nice',
#  'team',
#  'theater',
#  'return',
#  'stop',
#  'finally',
#  'maybe',
#  'die',
#  'order',
#  'person',
#  'past',
#  'miss',
#  'situation',
#  'title',
#  'view',
#  'example',
#  'perfect',
#  'cop',
#  'certainly',
#  'sort',
#  'joe',
#  'fine',
#  'version',
#  'stand',
#  'worth',
#  'note',
#  'piece',
#  'classic',
#  'cut',
#  'hope',
#  'video',
#  'consider',
#  'bring',
#  'drama',
#  'self',
#  'major',
#  'voice',
#  'early',
#  'white',
#  'beautiful',
#  'strong',
#  'production',
#  'body',
#  'event',
#  'upon',
#  'five',
#  'violence',
#  'heart',
#  'break',
#  'talent',
#  'killer',
#  'screenplay',
#  'daughter',
#  'nearly',
#  'short',
#  'close',
#  'wait',
#  'already',
#  'level',
#  'pull',
#  'ship',
#  'dark',
#  'room',
#  'four',
#  'deep',
#  'opening',
#  'thriller',
#  'light',
#  'age',
#  'obvious',
#  'dog',
#  'ask',
#  'disney',
#  'king',
#  'experience',
#  'chase',
#  'earth',
#  'learn',
#  'offer',
#  'guess',
#  'state',
#  'surprise',
#  'waste',
#  'throughout',
#  'figure',
#  'number',
#  'exactly',
#  'kevin',
#  'jack',
#  'others',
#  '1',
#  'hold',
#  'form',
#  'flick',
#  'plan',
#  'direction',
#  'romantic',
#  'twist',
#  'pace',
#  'art',
#  'realize',
#  'easy',
#  'computer',
#  'sometimes',
#  'career',
#  'dream',
#  'simple',
#  'fill',
#  'type',
#  'walk',
#  'filmmaker',
#  'touch',
#  'novel',
#  'gun',
#  'jackie',
#  'charm',
#  'planet',
#  'win',
#  'husband',
#  'rise',
#  'score',
#  'boring',
#  'tom',
#  'space',
#  'member',
#  'saw',
#  'carry',
#  'paul',
#  'truly',
#  'york',
#  'tale',
#  'oscar',
#  'drug',
#  'possible',
#  'battle',
#  'hell',
#  'peter',
#  'sequel',
#  'song',
#  'material',
#  'focus',
#  'wild',
#  'remember',
#  '3',
#  'decide',
#  'chance',
#  'extremely',
#  'rock',
#  'genre',
#  'smith',
#  'god',
#  'particularly',
#  'police',
#  'quickly',
#  'de',
#  'manages',
#  'attention',
#  'parent',
#  'stupid',
#  'happens',
#  'lee',
#  'shoot',
#  'escape',
#  'pay',
#  'usually',
#  'stay',
#  'none',
#  'mostly',
#  'fiction',
#  'villain',
#  'studio',
#  'yes',
#  'success',
#  'girlfriend',
#  'dr',
#  'flaw',
#  'cover',
#  'quality',
#  'image',
#  'detail',
#  'single',
#  'project',
#  'television',
#  'million',
#  'large',
#  'eventually',
#  'slow',
#  'co',
#  'except',
#  'middle',
#  'steal',
#  'mention',
#  'sit',
#  'low',
#  'across',
#  'van',
#  'law',
#  'theme',
#  'alone',
#  'crime',
#  'read',
#  'actress',
#  'attack',
#  'future',
#  'obviously',
#  'told',
#  'secret',
#  'oh',
#  'within',
#  'premise',
#  'water',
#  'williams',
#  'understand',
#  'complete',
#  'drive',
#  'impressive',
#  'recent',
#  'explain',
#  'mystery',
#  'emotional',
#  'batman',
#  'robin',
#  'amaze',
#  'history',
#  'science',
#  'cause',
#  'company',
#  'poor',
#  'living',
#  'wonderful',
#  'easily',
#  'somehow',
#  'country',
#  'important',
#  'effort',
#  'wish',
#  'aspect',
#  'office',
#  'harry',
#  'cool',
#  '4',
#  'street',
#  'ryan',
#  'control',
#  'among',
#  'motion',
#  'agent',
#  'whether',
#  'local',
#  'america',
#  'lie',
#  'fire',
#  'message',
#  'chris',
#  'mark',
#  'wedding',
#  'subject',
#  'fear',
#  'difficult',
#  'cross',
#  'jones',
#  'rich',
#  'serious',
#  'doubt',
#  'murphy',
#  'fast',
#  'entertainment',
#  'fail',
#  'happy',
#  'screenwriter',
#  'ben',
#  'near',
#  'third',
#  'critic',
#  'brings',
#  'class',
#  'reality',
#  'hilarious',
#  'dramatic',
#  'george',
#  'stuff',
#  'throw',
#  'basically',
#  'surprisingly',
#  'due',
#  'fly',
#  'produce',
#  'suspense',
#  'annoy',
#  'us',
#  'trouble',
#  'certain',
#  'william',
#  'ago',
#  'speak',
#  'answer',
#  'apparently',
#  'sexual',
#  'previous',
#  'bill',
#  'crew',
#  'similar',
#  'vampire',
#  'jim',
#  'budget',
#  'intelligent',
#  'emotion',
#  'general',
#  'smart',
#  'presence',
#  'blood',
#  'choice',
#  'business',
#  'appeal',
#  'personal',
#  'confuse',
#  'bob',
#  'visual',
#  'predictable',
#  'clear',
#  'party',
#  'decides',
#  'mission',
#  'producer',
#  'tone',
#  'wear',
#  'clever',
#  'approach',
#  'teen',
#  'scary',
#  'somewhat',
#  'beyond',
#  'romance',
#  'leaf',
#  'familiar',
#  'deliver',
#  'la',
#  'excellent',
#  'rat',
#  'sister',
#  'red',
#  'prison',
#  'favorite',
#  'date',
#  'ability',
#  'share',
#  'absolutely',
#  'excite',
#  'r',
#  'adult',
#  'successful',
#  'cinema',
#  'b',
#  'catch',
#  'giant',
#  'treat',
#  'frank',
#  'allow',
#  'mess',
#  'popular',
#  'discover',
#  'rule',
#  'anyway',
#  'box',
#  'potential',
#  'strike',
#  'trek',
#  'strange',
#  'effective',
#  'definitely',
#  'student',
#  'private',
#  'amount',
#  'nature',
#  'trailer',
#  'eddie',
#  'felt',
#  'immediately',
#  'shock',
#  'powerful',
#  'truman',
#  'victim',
#  'fails',
#  'thrill',
#  'hate',
#  'handle',
#  'free',
#  'continue',
#  'former',
#  'master',
#  'usual',
#  'seriously',
#  'appearance',
#  'track',
#  'martin',
#  'scott',
#  'pick',
#  'search',
#  'development',
#  'capture',
#  'blue',
#  'join',
#  'rating',
#  'neither',
#  'stone',
#  'week',
#  'sam',
#  'manage',
#  'huge',
#  'truth',
#  'convincing',
#  'grace',
#  'issue',
#  'straight',
#  'race',
#  'inside',
#  'solid',
#  'musical',
#  'unlike',
#  'perfectly',
#  'sweet',
#  'sign',
#  'enjoyable',
#  'animate',
#  'hunt',
#  'door',
#  'kiss',
#  'ape',
#  'purpose',
#  'serve',
#  'air',
#  'spend',
#  'reveal',
#  'haunt',
#  'cameron',
#  'otherwise',
#  'married',
#  'land',
#  'prove',
#  'gag',
#  'non',
#  'toy',
#  'suspect',
#  'decent',
#  'political',
#  'dance',
#  'grow',
#  'ex',
#  'sight',
#  'overall',
#  'front',
#  'merely',
#  'travel',
#  'likely',
#  'army',
#  'animation',
#  'drop',
#  'nick',
#  'west',
#  'imagine',
#  'depth',
#  'bunch',
#  'park',
#  'l',
#  'ten',
#  'reach',
#  'female',
#  'heard',
#  'government',
#  'require',
#  'society',
#  'bruce',
#  'baby',
#  'train',
#  'arm',
#  'e',
#  'pop',
#  'sell',
#  'respect',
#  'english',
#  'particular',
#  'towards',
#  'design',
#  'lover',
#  'background',
#  'fashion',
#  'adventure',
#  'richard',
#  'brilliant',
#  'actual',
#  'term',
#  'monster',
#  'struggle',
#  'silly',
#  'chan',
#  'ground',
#  'steve',
#  'various',
#  'spirit',
#  'succeed',
#  'award',
#  'modern',
#  'player',
#  'menace',
#  'queen',
#  'club',
#  'cold',
#  'talented',
#  'step',
#  'impact',
#  '8',
#  'memorable',
#  'impossible',
#  'raise',
#  'rush',
#  'steven',
#  'tension',
#  'amuse',
#  'titanic',
#  'mouth',
#  'suddenly',
#  'tim',
#  'double',
#  'mar',
#  'list',
#  'today',
#  'subtle',
#  'brought',
#  'hear',
#  'road',
#  'doctor',
#  'hop',
#  'suffer',
#  'carter',
#  'cannot',
#  '5',
#  'dollar',
#  'episode',
#  'month',
#  'terrible',
#  'detective',
#  'building',
#  'willis',
#  'compare',
#  'engage',
#  'ultimately',
#  'opportunity',
#  'entirely',
#  'key',
#  'roll',
#  'spielberg',
#  'promise',
#  'dumb',
#  'costume',
#  'color',
#  'disaster',
#  'ghost',
#  'cliche',
#  'soundtrack',
#  'officer',
#  '90',
#  'store',
#  'personality',
#  'slightly',
#  'fairly',
#  'hot',
#  'soldier',
#  'leader',
#  'male',
#  'pair',
#  'lawyer',
#  'sent',
#  'spent',
#  'complex',
#  'machine',
#  'awful',
#  'max',
#  'totally',
#  'rescue',
#  'recommend',
#  'angel',
#  'allen',
#  'woody',
#  'godzilla',
#  'ii',
#  'thin',
#  'delivers',
#  'beauty',
#  'climax',
#  'highly',
#  'partner',
#  'bug',
#  'minor',
#  'atmosphere',
#  'hill',
#  'vega',
#  'mike',
#  'trip',
#  'ridiculous',
#  'simon',
#  'longer',
#  'grant',
#  'adam',
#  'seven',
#  'basic',
#  'animal',
#  'camp',
#  'admit',
#  'cheap',
#  'six',
#  'outside',
#  'introduce',
#  'plenty',
#  'recently',
#  'x',
#  'realistic',
#  'hole',
#  'foot',
#  'twenty',
#  'jackson',
#  'clearly',
#  'sean',
#  'president',
#  'indeed',
#  'typical',
#  'sci',
#  'fi',
#  'british',
#  'flat',
#  'spot',
#  'period',
#  'dress',
#  'edit',
#  'julia',
#  'fit',
#  'whatever',
#  'edward',
#  'kick',
#  'lucas',
#  'standard',
#  'damn',
#  'earlier',
#  'cameo',
#  'concept',
#  'creature',
#  'quick',
#  'brain',
#  'buddy',
#  'constantly',
#  'frame',
#  'conclusion',
#  'cage',
#  'hire',
#  'jerry',
#  'brief',
#  'bore',
#  'heavy',
#  'college',
#  'teacher',
#  'energy',
#  'medium',
#  'tough',
#  'ride',
#  'wall',
#  'target',
#  'singer',
#  'island',
#  'intelligence',
#  'cute',
#  'lame',
#  'century',
#  'inspire',
#  'green',
#  'sing',
#  'dull',
#  'believable',
#  'violent',
#  'cinematography',
#  'aside',
#  'thanks',
#  'common',
#  'french',
#  '1998',
#  'appreciate',
#  'loud',
#  ...]

# %%
documents[0]
# Out:
# (['let',
#   'first',
#   'look',
#   'history',
#   'shark',
#   'film',
#   'unforgettable',
#   'jaw',
#   'excite',
#   'jaw',
#   '2',
#   'rather',
#   'flaky',
#   'jaw',
#   '3d',
#   'sometime',
#   'late',
#   '90',
#   'another',
#   'film',
#   'genre',
#   'seem',
#   'recall',
#   'son',
#   'jaw',
#   'return',
#   'wreak',
#   'revenge',
#   'something',
#   'like',
#   'magic',
#   'cgi',
#   'one',
#   'shark',
#   'simply',
#   'enough',
#   'deep',
#   'blue',
#   'sea',
#   '3',
#   'big',
#   'mean',
#   'really',
#   'smart',
#   'one',
#   'russell',
#   'frankiln',
#   'jackson',
#   'visit',
#   'aquatica',
#   'sea',
#   'bound',
#   'research',
#   'center',
#   'research',
#   'conduct',
#   'extraction',
#   'hormone',
#   'substance',
#   'found',
#   'uniquely',
#   'within',
#   'shark',
#   'brain',
#   'cure',
#   'reverse',
#   'effect',
#   'alzheimer',
#   'disease',
#   'substance',
#   'small',
#   'quantity',
#   'lead',
#   'researcher',
#   'dr',
#   'susan',
#   'macalaester',
#   'genetically',
#   'alters',
#   'shark',
#   'dna',
#   'grows',
#   'twice',
#   'size',
#   'brain',
#   'big',
#   'human',
#   'naturally',
#   'produce',
#   'much',
#   'treasure',
#   'hormone',
#   'sure',
#   'sun',
#   'set',
#   'west',
#   'shark',
#   'break',
#   'lose',
#   'wreaks',
#   'havoc',
#   'within',
#   'facility',
#   'hormone',
#   'extraction',
#   'procedure',
#   'flexibility',
#   'offer',
#   'cgi',
#   'shark',
#   'get',
#   'full',
#   'length',
#   'screen',
#   'time',
#   'predecessor',
#   'remote',
#   'control',
#   'rubber',
#   'suit',
#   'day',
#   'go',
#   'day',
#   'people',
#   'get',
#   'pull',
#   'water',
#   'water',
#   'turn',
#   'red',
#   'right',
#   'time',
#   'get',
#   'see',
#   'entire',
#   'gobble',
#   'action',
#   'float',
#   'limb',
#   'act',
#   'expect',
#   'average',
#   'action',
#   'film',
#   'jackson',
#   'fresh',
#   'jedi',
#   'master',
#   'role',
#   'phantom',
#   'menace',
#   'take',
#   'dark',
#   'side',
#   'force',
#   'different',
#   'kind',
#   'fit',
#   'well',
#   'wise',
#   'crack',
#   'line',
#   'cool',
#   'j',
#   'cook',
#   'role',
#   'preacher',
#   'film',
#   'steven',
#   'seagal',
#   'cook',
#   'could',
#   'dream',
#   'achieve',
#   'two',
#   'siege',
#   'film',
#   'deep',
#   'blue',
#   'sea',
#   'offer',
#   'psychological',
#   'thrill',
#   'jaw',
#   'offer',
#   'however',
#   'prove',
#   'refresh',
#   'follow',
#   'within',
#   'genre',
#   'full',
#   'visual',
#   'thrill',
#   'suspense',
#   'believe',
#   '\x05',
#   'humour',
#   'like',
#   'jurassic',
#   'park',
#   'water',
#   'nothing',
#   'stressful',
#   'pure',
#   'entertainment',
#   'renny',
#   'harlin',
#   'forgiven',
#   'make',
#   'cutthroat',
#   'island'],
#  'pos')

# %%
def get_feature_dict(words):
    
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
get_feature_dict(training_documents[0][0])
# Out:
# {'film': True,
#  'movie': False,
#  'one': True,
#  'make': True,
#  'like': True,
#  'character': False,
#  'get': True,
#  'see': True,
#  'go': True,
#  'time': True,
#  'well': True,
#  'scene': False,
#  'even': False,
#  'good': False,
#  'story': False,
#  'take': True,
#  'would': False,
#  'much': True,
#  'bad': False,
#  'also': False,
#  'come': False,
#  'give': False,
#  'look': True,
#  'two': True,
#  'way': False,
#  'seem': True,
#  'know': False,
#  'life': False,
#  'first': True,
#  'end': False,
#  'year': False,
#  '--': False,
#  'work': False,
#  'thing': False,
#  'say': False,
#  'plot': False,
#  'really': True,
#  'show': False,
#  'play': False,
#  'little': False,
#  'people': True,
#  'star': False,
#  'could': True,
#  'man': False,
#  'love': False,
#  'try': False,
#  'never': False,
#  'director': False,
#  'best': False,
#  'new': False,
#  'great': False,
#  'many': False,
#  'actor': False,
#  'big': True,
#  'action': True,
#  'watch': False,
#  'want': False,
#  'performance': False,
#  'find': False,
#  'think': False,
#  'u': False,
#  'role': True,
#  'act': True,
#  'another': True,
#  'audience': False,
#  'back': False,
#  'still': False,
#  'something': True,
#  'turn': True,
#  'world': False,
#  'however': True,
#  'old': False,
#  'day': True,
#  'set': True,
#  'every': False,
#  'guy': False,
#  'though': False,
#  'use': False,
#  'comedy': False,
#  'cast': False,
#  'enough': True,
#  'feel': False,
#  'begin': False,
#  'interest': False,
#  'part': False,
#  'actually': False,
#  'young': False,
#  'name': False,
#  'last': False,
#  'real': False,
#  'point': False,
#  'around': False,
#  'run': False,
#  'script': False,
#  'funny': False,
#  'effect': True,
#  'fact': False,
#  'right': True,
#  'may': False,
#  'write': False,
#  'long': False,
#  'woman': False,
#  'lot': False,
#  'minute': False,
#  'friend': False,
#  'place': False,
#  'almost': False,
#  'john': False,
#  'screen': True,
#  'nothing': True,
#  'line': True,
#  'moment': False,
#  'since': False,
#  'become': False,
#  'call': False,
#  'played': False,
#  'ever': False,
#  'tell': False,
#  'start': False,
#  'although': False,
#  'family': False,
#  'help': False,
#  'kill': False,
#  'original': False,
#  'without': False,
#  'problem': False,
#  'three': False,
#  'lead': True,
#  'picture': False,
#  'least': False,
#  'high': False,
#  'laugh': False,
#  'girl': False,
#  'sequence': False,
#  'need': False,
#  'might': False,
#  'away': False,
#  'fall': False,
#  'far': False,
#  'quite': False,
#  'put': False,
#  'course': False,
#  'american': False,
#  'keep': False,
#  'child': False,
#  'bit': False,
#  'rather': True,
#  'attempt': False,
#  'alien': False,
#  'include': False,
#  'always': False,
#  'kind': True,
#  'job': False,
#  'must': False,
#  'follow': True,
#  'special': False,
#  'anything': False,
#  'war': False,
#  'hour': False,
#  'yet': False,
#  'hard': False,
#  'wife': False,
#  'fun': False,
#  'feature': False,
#  'black': False,
#  'home': False,
#  'reason': False,
#  'instead': False,
#  'hand': False,
#  'head': False,
#  'hollywood': False,
#  'sense': False,
#  'lose': True,
#  'probably': False,
#  'men': False,
#  'kid': False,
#  'human': True,
#  'half': False,
#  'shot': False,
#  'mind': False,
#  'series': False,
#  'idea': False,
#  'move': False,
#  'pretty': False,
#  'involve': False,
#  'face': False,
#  'night': False,
#  'let': True,
#  'along': False,
#  'dialogue': False,
#  'direct': False,
#  'talk': False,
#  'everything': False,
#  'together': False,
#  'force': True,
#  'sure': True,
#  'believe': True,
#  'whole': False,
#  'money': False,
#  'sex': False,
#  'second': False,
#  'music': False,
#  'release': False,
#  'question': False,
#  'horror': False,
#  'becomes': False,
#  'father': False,
#  'save': False,
#  'thought': False,
#  'everyone': False,
#  'fight': False,
#  'appear': False,
#  'mother': False,
#  'city': False,
#  'boy': False,
#  'death': False,
#  'do': False,
#  'evil': False,
#  'next': False,
#  'especially': False,
#  'small': True,
#  'perhaps': False,
#  'eye': False,
#  'happen': False,
#  'brother': False,
#  'base': False,
#  'relationship': False,
#  'expect': True,
#  'couple': False,
#  'less': False,
#  'case': False,
#  'writer': False,
#  'different': True,
#  'meet': False,
#  'rest': False,
#  'change': False,
#  'mean': True,
#  'joke': False,
#  'sound': False,
#  'review': False,
#  '2': True,
#  '10': False,
#  'whose': False,
#  'late': True,
#  'completely': False,
#  'care': False,
#  'create': False,
#  'fan': False,
#  'book': False,
#  'several': False,
#  'comic': False,
#  'michael': False,
#  'anyone': False,
#  'word': False,
#  'school': False,
#  'live': False,
#  'hit': False,
#  'suppose': False,
#  'left': False,
#  'add': False,
#  'true': False,
#  'simply': True,
#  'game': False,
#  'main': False,
#  'entertain': False,
#  'top': False,
#  'humor': False,
#  'someone': False,
#  'lack': False,
#  'mr': False,
#  'car': False,
#  'matter': False,
#  'tv': False,
#  'leave': False,
#  'found': True,
#  'house': False,
#  'either': False,
#  'james': False,
#  'wrong': False,
#  'side': True,
#  'often': False,
#  'support': False,
#  'town': False,
#  'viewer': False,
#  'group': False,
#  'wonder': False,
#  'david': False,
#  'else': False,
#  'power': False,
#  'enjoy': False,
#  'hero': False,
#  'full': True,
#  'deal': False,
#  'robert': False,
#  'present': False,
#  'later': False,
#  'result': False,
#  'credit': False,
#  'behind': False,
#  'final': False,
#  'soon': False,
#  'dead': False,
#  'camera': False,
#  'scream': False,
#  'open': False,
#  'unfortunately': False,
#  'provide': False,
#  'murder': False,
#  'able': False,
#  'son': True,
#  'style': False,
#  'summer': False,
#  'element': False,
#  'despite': False,
#  'entire': True,
#  'nice': False,
#  'team': False,
#  'theater': False,
#  'return': True,
#  'stop': False,
#  'finally': False,
#  'maybe': False,
#  'die': False,
#  'order': False,
#  'person': False,
#  'past': False,
#  'miss': False,
#  'situation': False,
#  'title': False,
#  'view': False,
#  'example': False,
#  'perfect': False,
#  'cop': False,
#  'certainly': False,
#  'sort': False,
#  'joe': False,
#  'fine': False,
#  'version': False,
#  'stand': False,
#  'worth': False,
#  'note': False,
#  'piece': False,
#  'classic': False,
#  'cut': False,
#  'hope': False,
#  'video': False,
#  'consider': False,
#  'bring': False,
#  'drama': False,
#  'self': False,
#  'major': False,
#  'voice': False,
#  'early': False,
#  'white': False,
#  'beautiful': False,
#  'strong': False,
#  'production': False,
#  'body': False,
#  'event': False,
#  'upon': False,
#  'five': False,
#  'violence': False,
#  'heart': False,
#  'break': True,
#  'talent': False,
#  'killer': False,
#  'screenplay': False,
#  'daughter': False,
#  'nearly': False,
#  'short': False,
#  'close': False,
#  'wait': False,
#  'already': False,
#  'level': False,
#  'pull': True,
#  'ship': False,
#  'dark': True,
#  'room': False,
#  'four': False,
#  'deep': True,
#  'opening': False,
#  'thriller': False,
#  'light': False,
#  'age': False,
#  'obvious': False,
#  'dog': False,
#  'ask': False,
#  'disney': False,
#  'king': False,
#  'experience': False,
#  'chase': False,
#  'earth': False,
#  'learn': False,
#  'offer': True,
#  'guess': False,
#  'state': False,
#  'surprise': False,
#  'waste': False,
#  'throughout': False,
#  'figure': False,
#  'number': False,
#  'exactly': False,
#  'kevin': False,
#  'jack': False,
#  'others': False,
#  '1': False,
#  'hold': False,
#  'form': False,
#  'flick': False,
#  'plan': False,
#  'direction': False,
#  'romantic': False,
#  'twist': False,
#  'pace': False,
#  'art': False,
#  'realize': False,
#  'easy': False,
#  'computer': False,
#  'sometimes': False,
#  'career': False,
#  'dream': True,
#  'simple': False,
#  'fill': False,
#  'type': False,
#  'walk': False,
#  'filmmaker': False,
#  'touch': False,
#  'novel': False,
#  'gun': False,
#  'jackie': False,
#  'charm': False,
#  'planet': False,
#  'win': False,
#  'husband': False,
#  'rise': False,
#  'score': False,
#  'boring': False,
#  'tom': False,
#  'space': False,
#  'member': False,
#  'saw': False,
#  'carry': False,
#  'paul': False,
#  'truly': False,
#  'york': False,
#  'tale': False,
#  'oscar': False,
#  'drug': False,
#  'possible': False,
#  'battle': False,
#  'hell': False,
#  'peter': False,
#  'sequel': False,
#  'song': False,
#  'material': False,
#  'focus': False,
#  'wild': False,
#  'remember': False,
#  '3': True,
#  'decide': False,
#  'chance': False,
#  'extremely': False,
#  'rock': False,
#  'genre': True,
#  'smith': False,
#  'god': False,
#  'particularly': False,
#  'police': False,
#  'quickly': False,
#  'de': False,
#  'manages': False,
#  'attention': False,
#  'parent': False,
#  'stupid': False,
#  'happens': False,
#  'lee': False,
#  'shoot': False,
#  'escape': False,
#  'pay': False,
#  'usually': False,
#  'stay': False,
#  'none': False,
#  'mostly': False,
#  'fiction': False,
#  'villain': False,
#  'studio': False,
#  'yes': False,
#  'success': False,
#  'girlfriend': False,
#  'dr': True,
#  'flaw': False,
#  'cover': False,
#  'quality': False,
#  'image': False,
#  'detail': False,
#  'single': False,
#  'project': False,
#  'television': False,
#  'million': False,
#  'large': False,
#  'eventually': False,
#  'slow': False,
#  'co': False,
#  'except': False,
#  'middle': False,
#  'steal': False,
#  'mention': False,
#  'sit': False,
#  'low': False,
#  'across': False,
#  'van': False,
#  'law': False,
#  'theme': False,
#  'alone': False,
#  'crime': False,
#  'read': False,
#  'actress': False,
#  'attack': False,
#  'future': False,
#  'obviously': False,
#  'told': False,
#  'secret': False,
#  'oh': False,
#  'within': True,
#  'premise': False,
#  'water': True,
#  'williams': False,
#  'understand': False,
#  'complete': False,
#  'drive': False,
#  'impressive': False,
#  'recent': False,
#  'explain': False,
#  'mystery': False,
#  'emotional': False,
#  'batman': False,
#  'robin': False,
#  'amaze': False,
#  'history': True,
#  'science': False,
#  'cause': False,
#  'company': False,
#  'poor': False,
#  'living': False,
#  'wonderful': False,
#  'easily': False,
#  'somehow': False,
#  'country': False,
#  'important': False,
#  'effort': False,
#  'wish': False,
#  'aspect': False,
#  'office': False,
#  'harry': False,
#  'cool': True,
#  '4': False,
#  'street': False,
#  'ryan': False,
#  'control': True,
#  'among': False,
#  'motion': False,
#  'agent': False,
#  'whether': False,
#  'local': False,
#  'america': False,
#  'lie': False,
#  'fire': False,
#  'message': False,
#  'chris': False,
#  'mark': False,
#  'wedding': False,
#  'subject': False,
#  'fear': False,
#  'difficult': False,
#  'cross': False,
#  'jones': False,
#  'rich': False,
#  'serious': False,
#  'doubt': False,
#  'murphy': False,
#  'fast': False,
#  'entertainment': True,
#  'fail': False,
#  'happy': False,
#  'screenwriter': False,
#  'ben': False,
#  'near': False,
#  'third': False,
#  'critic': False,
#  'brings': False,
#  'class': False,
#  'reality': False,
#  'hilarious': False,
#  'dramatic': False,
#  'george': False,
#  'stuff': False,
#  'throw': False,
#  'basically': False,
#  'surprisingly': False,
#  'due': False,
#  'fly': False,
#  'produce': True,
#  'suspense': True,
#  'annoy': False,
#  'us': False,
#  'trouble': False,
#  'certain': False,
#  'william': False,
#  'ago': False,
#  'speak': False,
#  'answer': False,
#  'apparently': False,
#  'sexual': False,
#  'previous': False,
#  'bill': False,
#  'crew': False,
#  'similar': False,
#  'vampire': False,
#  'jim': False,
#  'budget': False,
#  'intelligent': False,
#  'emotion': False,
#  'general': False,
#  'smart': True,
#  'presence': False,
#  'blood': False,
#  'choice': False,
#  'business': False,
#  'appeal': False,
#  'personal': False,
#  'confuse': False,
#  'bob': False,
#  'visual': True,
#  'predictable': False,
#  'clear': False,
#  'party': False,
#  'decides': False,
#  'mission': False,
#  'producer': False,
#  'tone': False,
#  'wear': False,
#  'clever': False,
#  'approach': False,
#  'teen': False,
#  'scary': False,
#  'somewhat': False,
#  'beyond': False,
#  'romance': False,
#  'leaf': False,
#  'familiar': False,
#  'deliver': False,
#  'la': False,
#  'excellent': False,
#  'rat': False,
#  'sister': False,
#  'red': True,
#  'prison': False,
#  'favorite': False,
#  'date': False,
#  'ability': False,
#  'share': False,
#  'absolutely': False,
#  'excite': True,
#  'r': False,
#  'adult': False,
#  'successful': False,
#  'cinema': False,
#  'b': False,
#  'catch': False,
#  'giant': False,
#  'treat': False,
#  'frank': False,
#  'allow': False,
#  'mess': False,
#  'popular': False,
#  'discover': False,
#  'rule': False,
#  'anyway': False,
#  'box': False,
#  'potential': False,
#  'strike': False,
#  'trek': False,
#  'strange': False,
#  'effective': False,
#  'definitely': False,
#  'student': False,
#  'private': False,
#  'amount': False,
#  'nature': False,
#  'trailer': False,
#  'eddie': False,
#  'felt': False,
#  'immediately': False,
#  'shock': False,
#  'powerful': False,
#  'truman': False,
#  'victim': False,
#  'fails': False,
#  'thrill': True,
#  'hate': False,
#  'handle': False,
#  'free': False,
#  'continue': False,
#  'former': False,
#  'master': True,
#  'usual': False,
#  'seriously': False,
#  'appearance': False,
#  'track': False,
#  'martin': False,
#  'scott': False,
#  'pick': False,
#  'search': False,
#  'development': False,
#  'capture': False,
#  'blue': True,
#  'join': False,
#  'rating': False,
#  'neither': False,
#  'stone': False,
#  'week': False,
#  'sam': False,
#  'manage': False,
#  'huge': False,
#  'truth': False,
#  'convincing': False,
#  'grace': False,
#  'issue': False,
#  'straight': False,
#  'race': False,
#  'inside': False,
#  'solid': False,
#  'musical': False,
#  'unlike': False,
#  'perfectly': False,
#  'sweet': False,
#  'sign': False,
#  'enjoyable': False,
#  'animate': False,
#  'hunt': False,
#  'door': False,
#  'kiss': False,
#  'ape': False,
#  'purpose': False,
#  'serve': False,
#  'air': False,
#  'spend': False,
#  'reveal': False,
#  'haunt': False,
#  'cameron': False,
#  'otherwise': False,
#  'married': False,
#  'land': False,
#  'prove': True,
#  'gag': False,
#  'non': False,
#  'toy': False,
#  'suspect': False,
#  'decent': False,
#  'political': False,
#  'dance': False,
#  'grow': False,
#  'ex': False,
#  'sight': False,
#  'overall': False,
#  'front': False,
#  'merely': False,
#  'travel': False,
#  'likely': False,
#  'army': False,
#  'animation': False,
#  'drop': False,
#  'nick': False,
#  'west': True,
#  'imagine': False,
#  'depth': False,
#  'bunch': False,
#  'park': True,
#  'l': False,
#  'ten': False,
#  'reach': False,
#  'female': False,
#  'heard': False,
#  'government': False,
#  'require': False,
#  'society': False,
#  'bruce': False,
#  'baby': False,
#  'train': False,
#  'arm': False,
#  'e': False,
#  'pop': False,
#  'sell': False,
#  'respect': False,
#  'english': False,
#  'particular': False,
#  'towards': False,
#  'design': False,
#  'lover': False,
#  'background': False,
#  'fashion': False,
#  'adventure': False,
#  'richard': False,
#  'brilliant': False,
#  'actual': False,
#  'term': False,
#  'monster': False,
#  'struggle': False,
#  'silly': False,
#  'chan': False,
#  'ground': False,
#  'steve': False,
#  'various': False,
#  'spirit': False,
#  'succeed': False,
#  'award': False,
#  'modern': False,
#  'player': False,
#  'menace': True,
#  'queen': False,
#  'club': False,
#  'cold': False,
#  'talented': False,
#  'step': False,
#  'impact': False,
#  '8': False,
#  'memorable': False,
#  'impossible': False,
#  'raise': False,
#  'rush': False,
#  'steven': True,
#  'tension': False,
#  'amuse': False,
#  'titanic': False,
#  'mouth': False,
#  'suddenly': False,
#  'tim': False,
#  'double': False,
#  'mar': False,
#  'list': False,
#  'today': False,
#  'subtle': False,
#  'brought': False,
#  'hear': False,
#  'road': False,
#  'doctor': False,
#  'hop': False,
#  'suffer': False,
#  'carter': False,
#  'cannot': False,
#  '5': False,
#  'dollar': False,
#  'episode': False,
#  'month': False,
#  'terrible': False,
#  'detective': False,
#  'building': False,
#  'willis': False,
#  'compare': False,
#  'engage': False,
#  'ultimately': False,
#  'opportunity': False,
#  'entirely': False,
#  'key': False,
#  'roll': False,
#  'spielberg': False,
#  'promise': False,
#  'dumb': False,
#  'costume': False,
#  'color': False,
#  'disaster': False,
#  'ghost': False,
#  'cliche': False,
#  'soundtrack': False,
#  'officer': False,
#  '90': True,
#  'store': False,
#  'personality': False,
#  'slightly': False,
#  'fairly': False,
#  'hot': False,
#  'soldier': False,
#  'leader': False,
#  'male': False,
#  'pair': False,
#  'lawyer': False,
#  'sent': False,
#  'spent': False,
#  'complex': False,
#  'machine': False,
#  'awful': False,
#  'max': False,
#  'totally': False,
#  'rescue': False,
#  'recommend': False,
#  'angel': False,
#  'allen': False,
#  'woody': False,
#  'godzilla': False,
#  'ii': False,
#  'thin': False,
#  'delivers': False,
#  'beauty': False,
#  'climax': False,
#  'highly': False,
#  'partner': False,
#  'bug': False,
#  'minor': False,
#  'atmosphere': False,
#  'hill': False,
#  'vega': False,
#  'mike': False,
#  'trip': False,
#  'ridiculous': False,
#  'simon': False,
#  'longer': False,
#  'grant': False,
#  'adam': False,
#  'seven': False,
#  'basic': False,
#  'animal': False,
#  'camp': False,
#  'admit': False,
#  'cheap': False,
#  'six': False,
#  'outside': False,
#  'introduce': False,
#  'plenty': False,
#  'recently': False,
#  'x': False,
#  'realistic': False,
#  'hole': False,
#  'foot': False,
#  'twenty': False,
#  'jackson': True,
#  'clearly': False,
#  'sean': False,
#  'president': False,
#  'indeed': False,
#  'typical': False,
#  'sci': False,
#  'fi': False,
#  'british': False,
#  'flat': False,
#  'spot': False,
#  'period': False,
#  'dress': False,
#  'edit': False,
#  'julia': False,
#  'fit': True,
#  'whatever': False,
#  'edward': False,
#  'kick': False,
#  'lucas': False,
#  'standard': False,
#  'damn': False,
#  'earlier': False,
#  'cameo': False,
#  'concept': False,
#  'creature': False,
#  'quick': False,
#  'brain': True,
#  'buddy': False,
#  'constantly': False,
#  'frame': False,
#  'conclusion': False,
#  'cage': False,
#  'hire': False,
#  'jerry': False,
#  'brief': False,
#  'bore': False,
#  'heavy': False,
#  'college': False,
#  'teacher': False,
#  'energy': False,
#  'medium': False,
#  'tough': False,
#  'ride': False,
#  'wall': False,
#  'target': False,
#  'singer': False,
#  'island': True,
#  'intelligence': False,
#  'cute': False,
#  'lame': False,
#  'century': False,
#  'inspire': False,
#  'green': False,
#  'sing': False,
#  'dull': False,
#  'believable': False,
#  'violent': False,
#  'cinematography': False,
#  'aside': False,
#  'thanks': False,
#  'common': False,
#  'french': False,
#  '1998': False,
#  'appreciate': False,
#  'loud': False,
#  ...}

# %%
training_data =[(get_feature_dict(doc), category) for doc, category in training_documents]
testing_data =[(get_feature_dict(doc), category) for doc, category in testing_documents]

# %%
training_data[0]
# Out:
# ({'film': True,
#   'movie': False,
#   'one': True,
#   'make': True,
#   'like': True,
#   'character': False,
#   'get': True,
#   'see': True,
#   'go': True,
#   'time': True,
#   'well': True,
#   'scene': False,
#   'even': False,
#   'good': False,
#   'story': False,
#   'take': True,
#   'would': False,
#   'much': True,
#   'bad': False,
#   'also': False,
#   'come': False,
#   'give': False,
#   'look': True,
#   'two': True,
#   'way': False,
#   'seem': True,
#   'know': False,
#   'life': False,
#   'first': True,
#   'end': False,
#   'year': False,
#   '--': False,
#   'work': False,
#   'thing': False,
#   'say': False,
#   'plot': False,
#   'really': True,
#   'show': False,
#   'play': False,
#   'little': False,
#   'people': True,
#   'star': False,
#   'could': True,
#   'man': False,
#   'love': False,
#   'try': False,
#   'never': False,
#   'director': False,
#   'best': False,
#   'new': False,
#   'great': False,
#   'many': False,
#   'actor': False,
#   'big': True,
#   'action': True,
#   'watch': False,
#   'want': False,
#   'performance': False,
#   'find': False,
#   'think': False,
#   'u': False,
#   'role': True,
#   'act': True,
#   'another': True,
#   'audience': False,
#   'back': False,
#   'still': False,
#   'something': True,
#   'turn': True,
#   'world': False,
#   'however': True,
#   'old': False,
#   'day': True,
#   'set': True,
#   'every': False,
#   'guy': False,
#   'though': False,
#   'use': False,
#   'comedy': False,
#   'cast': False,
#   'enough': True,
#   'feel': False,
#   'begin': False,
#   'interest': False,
#   'part': False,
#   'actually': False,
#   'young': False,
#   'name': False,
#   'last': False,
#   'real': False,
#   'point': False,
#   'around': False,
#   'run': False,
#   'script': False,
#   'funny': False,
#   'effect': True,
#   'fact': False,
#   'right': True,
#   'may': False,
#   'write': False,
#   'long': False,
#   'woman': False,
#   'lot': False,
#   'minute': False,
#   'friend': False,
#   'place': False,
#   'almost': False,
#   'john': False,
#   'screen': True,
#   'nothing': True,
#   'line': True,
#   'moment': False,
#   'since': False,
#   'become': False,
#   'call': False,
#   'played': False,
#   'ever': False,
#   'tell': False,
#   'start': False,
#   'although': False,
#   'family': False,
#   'help': False,
#   'kill': False,
#   'original': False,
#   'without': False,
#   'problem': False,
#   'three': False,
#   'lead': True,
#   'picture': False,
#   'least': False,
#   'high': False,
#   'laugh': False,
#   'girl': False,
#   'sequence': False,
#   'need': False,
#   'might': False,
#   'away': False,
#   'fall': False,
#   'far': False,
#   'quite': False,
#   'put': False,
#   'course': False,
#   'american': False,
#   'keep': False,
#   'child': False,
#   'bit': False,
#   'rather': True,
#   'attempt': False,
#   'alien': False,
#   'include': False,
#   'always': False,
#   'kind': True,
#   'job': False,
#   'must': False,
#   'follow': True,
#   'special': False,
#   'anything': False,
#   'war': False,
#   'hour': False,
#   'yet': False,
#   'hard': False,
#   'wife': False,
#   'fun': False,
#   'feature': False,
#   'black': False,
#   'home': False,
#   'reason': False,
#   'instead': False,
#   'hand': False,
#   'head': False,
#   'hollywood': False,
#   'sense': False,
#   'lose': True,
#   'probably': False,
#   'men': False,
#   'kid': False,
#   'human': True,
#   'half': False,
#   'shot': False,
#   'mind': False,
#   'series': False,
#   'idea': False,
#   'move': False,
#   'pretty': False,
#   'involve': False,
#   'face': False,
#   'night': False,
#   'let': True,
#   'along': False,
#   'dialogue': False,
#   'direct': False,
#   'talk': False,
#   'everything': False,
#   'together': False,
#   'force': True,
#   'sure': True,
#   'believe': True,
#   'whole': False,
#   'money': False,
#   'sex': False,
#   'second': False,
#   'music': False,
#   'release': False,
#   'question': False,
#   'horror': False,
#   'becomes': False,
#   'father': False,
#   'save': False,
#   'thought': False,
#   'everyone': False,
#   'fight': False,
#   'appear': False,
#   'mother': False,
#   'city': False,
#   'boy': False,
#   'death': False,
#   'do': False,
#   'evil': False,
#   'next': False,
#   'especially': False,
#   'small': True,
#   'perhaps': False,
#   'eye': False,
#   'happen': False,
#   'brother': False,
#   'base': False,
#   'relationship': False,
#   'expect': True,
#   'couple': False,
#   'less': False,
#   'case': False,
#   'writer': False,
#   'different': True,
#   'meet': False,
#   'rest': False,
#   'change': False,
#   'mean': True,
#   'joke': False,
#   'sound': False,
#   'review': False,
#   '2': True,
#   '10': False,
#   'whose': False,
#   'late': True,
#   'completely': False,
#   'care': False,
#   'create': False,
#   'fan': False,
#   'book': False,
#   'several': False,
#   'comic': False,
#   'michael': False,
#   'anyone': False,
#   'word': False,
#   'school': False,
#   'live': False,
#   'hit': False,
#   'suppose': False,
#   'left': False,
#   'add': False,
#   'true': False,
#   'simply': True,
#   'game': False,
#   'main': False,
#   'entertain': False,
#   'top': False,
#   'humor': False,
#   'someone': False,
#   'lack': False,
#   'mr': False,
#   'car': False,
#   'matter': False,
#   'tv': False,
#   'leave': False,
#   'found': True,
#   'house': False,
#   'either': False,
#   'james': False,
#   'wrong': False,
#   'side': True,
#   'often': False,
#   'support': False,
#   'town': False,
#   'viewer': False,
#   'group': False,
#   'wonder': False,
#   'david': False,
#   'else': False,
#   'power': False,
#   'enjoy': False,
#   'hero': False,
#   'full': True,
#   'deal': False,
#   'robert': False,
#   'present': False,
#   'later': False,
#   'result': False,
#   'credit': False,
#   'behind': False,
#   'final': False,
#   'soon': False,
#   'dead': False,
#   'camera': False,
#   'scream': False,
#   'open': False,
#   'unfortunately': False,
#   'provide': False,
#   'murder': False,
#   'able': False,
#   'son': True,
#   'style': False,
#   'summer': False,
#   'element': False,
#   'despite': False,
#   'entire': True,
#   'nice': False,
#   'team': False,
#   'theater': False,
#   'return': True,
#   'stop': False,
#   'finally': False,
#   'maybe': False,
#   'die': False,
#   'order': False,
#   'person': False,
#   'past': False,
#   'miss': False,
#   'situation': False,
#   'title': False,
#   'view': False,
#   'example': False,
#   'perfect': False,
#   'cop': False,
#   'certainly': False,
#   'sort': False,
#   'joe': False,
#   'fine': False,
#   'version': False,
#   'stand': False,
#   'worth': False,
#   'note': False,
#   'piece': False,
#   'classic': False,
#   'cut': False,
#   'hope': False,
#   'video': False,
#   'consider': False,
#   'bring': False,
#   'drama': False,
#   'self': False,
#   'major': False,
#   'voice': False,
#   'early': False,
#   'white': False,
#   'beautiful': False,
#   'strong': False,
#   'production': False,
#   'body': False,
#   'event': False,
#   'upon': False,
#   'five': False,
#   'violence': False,
#   'heart': False,
#   'break': True,
#   'talent': False,
#   'killer': False,
#   'screenplay': False,
#   'daughter': False,
#   'nearly': False,
#   'short': False,
#   'close': False,
#   'wait': False,
#   'already': False,
#   'level': False,
#   'pull': True,
#   'ship': False,
#   'dark': True,
#   'room': False,
#   'four': False,
#   'deep': True,
#   'opening': False,
#   'thriller': False,
#   'light': False,
#   'age': False,
#   'obvious': False,
#   'dog': False,
#   'ask': False,
#   'disney': False,
#   'king': False,
#   'experience': False,
#   'chase': False,
#   'earth': False,
#   'learn': False,
#   'offer': True,
#   'guess': False,
#   'state': False,
#   'surprise': False,
#   'waste': False,
#   'throughout': False,
#   'figure': False,
#   'number': False,
#   'exactly': False,
#   'kevin': False,
#   'jack': False,
#   'others': False,
#   '1': False,
#   'hold': False,
#   'form': False,
#   'flick': False,
#   'plan': False,
#   'direction': False,
#   'romantic': False,
#   'twist': False,
#   'pace': False,
#   'art': False,
#   'realize': False,
#   'easy': False,
#   'computer': False,
#   'sometimes': False,
#   'career': False,
#   'dream': True,
#   'simple': False,
#   'fill': False,
#   'type': False,
#   'walk': False,
#   'filmmaker': False,
#   'touch': False,
#   'novel': False,
#   'gun': False,
#   'jackie': False,
#   'charm': False,
#   'planet': False,
#   'win': False,
#   'husband': False,
#   'rise': False,
#   'score': False,
#   'boring': False,
#   'tom': False,
#   'space': False,
#   'member': False,
#   'saw': False,
#   'carry': False,
#   'paul': False,
#   'truly': False,
#   'york': False,
#   'tale': False,
#   'oscar': False,
#   'drug': False,
#   'possible': False,
#   'battle': False,
#   'hell': False,
#   'peter': False,
#   'sequel': False,
#   'song': False,
#   'material': False,
#   'focus': False,
#   'wild': False,
#   'remember': False,
#   '3': True,
#   'decide': False,
#   'chance': False,
#   'extremely': False,
#   'rock': False,
#   'genre': True,
#   'smith': False,
#   'god': False,
#   'particularly': False,
#   'police': False,
#   'quickly': False,
#   'de': False,
#   'manages': False,
#   'attention': False,
#   'parent': False,
#   'stupid': False,
#   'happens': False,
#   'lee': False,
#   'shoot': False,
#   'escape': False,
#   'pay': False,
#   'usually': False,
#   'stay': False,
#   'none': False,
#   'mostly': False,
#   'fiction': False,
#   'villain': False,
#   'studio': False,
#   'yes': False,
#   'success': False,
#   'girlfriend': False,
#   'dr': True,
#   'flaw': False,
#   'cover': False,
#   'quality': False,
#   'image': False,
#   'detail': False,
#   'single': False,
#   'project': False,
#   'television': False,
#   'million': False,
#   'large': False,
#   'eventually': False,
#   'slow': False,
#   'co': False,
#   'except': False,
#   'middle': False,
#   'steal': False,
#   'mention': False,
#   'sit': False,
#   'low': False,
#   'across': False,
#   'van': False,
#   'law': False,
#   'theme': False,
#   'alone': False,
#   'crime': False,
#   'read': False,
#   'actress': False,
#   'attack': False,
#   'future': False,
#   'obviously': False,
#   'told': False,
#   'secret': False,
#   'oh': False,
#   'within': True,
#   'premise': False,
#   'water': True,
#   'williams': False,
#   'understand': False,
#   'complete': False,
#   'drive': False,
#   'impressive': False,
#   'recent': False,
#   'explain': False,
#   'mystery': False,
#   'emotional': False,
#   'batman': False,
#   'robin': False,
#   'amaze': False,
#   'history': True,
#   'science': False,
#   'cause': False,
#   'company': False,
#   'poor': False,
#   'living': False,
#   'wonderful': False,
#   'easily': False,
#   'somehow': False,
#   'country': False,
#   'important': False,
#   'effort': False,
#   'wish': False,
#   'aspect': False,
#   'office': False,
#   'harry': False,
#   'cool': True,
#   '4': False,
#   'street': False,
#   'ryan': False,
#   'control': True,
#   'among': False,
#   'motion': False,
#   'agent': False,
#   'whether': False,
#   'local': False,
#   'america': False,
#   'lie': False,
#   'fire': False,
#   'message': False,
#   'chris': False,
#   'mark': False,
#   'wedding': False,
#   'subject': False,
#   'fear': False,
#   'difficult': False,
#   'cross': False,
#   'jones': False,
#   'rich': False,
#   'serious': False,
#   'doubt': False,
#   'murphy': False,
#   'fast': False,
#   'entertainment': True,
#   'fail': False,
#   'happy': False,
#   'screenwriter': False,
#   'ben': False,
#   'near': False,
#   'third': False,
#   'critic': False,
#   'brings': False,
#   'class': False,
#   'reality': False,
#   'hilarious': False,
#   'dramatic': False,
#   'george': False,
#   'stuff': False,
#   'throw': False,
#   'basically': False,
#   'surprisingly': False,
#   'due': False,
#   'fly': False,
#   'produce': True,
#   'suspense': True,
#   'annoy': False,
#   'us': False,
#   'trouble': False,
#   'certain': False,
#   'william': False,
#   'ago': False,
#   'speak': False,
#   'answer': False,
#   'apparently': False,
#   'sexual': False,
#   'previous': False,
#   'bill': False,
#   'crew': False,
#   'similar': False,
#   'vampire': False,
#   'jim': False,
#   'budget': False,
#   'intelligent': False,
#   'emotion': False,
#   'general': False,
#   'smart': True,
#   'presence': False,
#   'blood': False,
#   'choice': False,
#   'business': False,
#   'appeal': False,
#   'personal': False,
#   'confuse': False,
#   'bob': False,
#   'visual': True,
#   'predictable': False,
#   'clear': False,
#   'party': False,
#   'decides': False,
#   'mission': False,
#   'producer': False,
#   'tone': False,
#   'wear': False,
#   'clever': False,
#   'approach': False,
#   'teen': False,
#   'scary': False,
#   'somewhat': False,
#   'beyond': False,
#   'romance': False,
#   'leaf': False,
#   'familiar': False,
#   'deliver': False,
#   'la': False,
#   'excellent': False,
#   'rat': False,
#   'sister': False,
#   'red': True,
#   'prison': False,
#   'favorite': False,
#   'date': False,
#   'ability': False,
#   'share': False,
#   'absolutely': False,
#   'excite': True,
#   'r': False,
#   'adult': False,
#   'successful': False,
#   'cinema': False,
#   'b': False,
#   'catch': False,
#   'giant': False,
#   'treat': False,
#   'frank': False,
#   'allow': False,
#   'mess': False,
#   'popular': False,
#   'discover': False,
#   'rule': False,
#   'anyway': False,
#   'box': False,
#   'potential': False,
#   'strike': False,
#   'trek': False,
#   'strange': False,
#   'effective': False,
#   'definitely': False,
#   'student': False,
#   'private': False,
#   'amount': False,
#   'nature': False,
#   'trailer': False,
#   'eddie': False,
#   'felt': False,
#   'immediately': False,
#   'shock': False,
#   'powerful': False,
#   'truman': False,
#   'victim': False,
#   'fails': False,
#   'thrill': True,
#   'hate': False,
#   'handle': False,
#   'free': False,
#   'continue': False,
#   'former': False,
#   'master': True,
#   'usual': False,
#   'seriously': False,
#   'appearance': False,
#   'track': False,
#   'martin': False,
#   'scott': False,
#   'pick': False,
#   'search': False,
#   'development': False,
#   'capture': False,
#   'blue': True,
#   'join': False,
#   'rating': False,
#   'neither': False,
#   'stone': False,
#   'week': False,
#   'sam': False,
#   'manage': False,
#   'huge': False,
#   'truth': False,
#   'convincing': False,
#   'grace': False,
#   'issue': False,
#   'straight': False,
#   'race': False,
#   'inside': False,
#   'solid': False,
#   'musical': False,
#   'unlike': False,
#   'perfectly': False,
#   'sweet': False,
#   'sign': False,
#   'enjoyable': False,
#   'animate': False,
#   'hunt': False,
#   'door': False,
#   'kiss': False,
#   'ape': False,
#   'purpose': False,
#   'serve': False,
#   'air': False,
#   'spend': False,
#   'reveal': False,
#   'haunt': False,
#   'cameron': False,
#   'otherwise': False,
#   'married': False,
#   'land': False,
#   'prove': True,
#   'gag': False,
#   'non': False,
#   'toy': False,
#   'suspect': False,
#   'decent': False,
#   'political': False,
#   'dance': False,
#   'grow': False,
#   'ex': False,
#   'sight': False,
#   'overall': False,
#   'front': False,
#   'merely': False,
#   'travel': False,
#   'likely': False,
#   'army': False,
#   'animation': False,
#   'drop': False,
#   'nick': False,
#   'west': True,
#   'imagine': False,
#   'depth': False,
#   'bunch': False,
#   'park': True,
#   'l': False,
#   'ten': False,
#   'reach': False,
#   'female': False,
#   'heard': False,
#   'government': False,
#   'require': False,
#   'society': False,
#   'bruce': False,
#   'baby': False,
#   'train': False,
#   'arm': False,
#   'e': False,
#   'pop': False,
#   'sell': False,
#   'respect': False,
#   'english': False,
#   'particular': False,
#   'towards': False,
#   'design': False,
#   'lover': False,
#   'background': False,
#   'fashion': False,
#   'adventure': False,
#   'richard': False,
#   'brilliant': False,
#   'actual': False,
#   'term': False,
#   'monster': False,
#   'struggle': False,
#   'silly': False,
#   'chan': False,
#   'ground': False,
#   'steve': False,
#   'various': False,
#   'spirit': False,
#   'succeed': False,
#   'award': False,
#   'modern': False,
#   'player': False,
#   'menace': True,
#   'queen': False,
#   'club': False,
#   'cold': False,
#   'talented': False,
#   'step': False,
#   'impact': False,
#   '8': False,
#   'memorable': False,
#   'impossible': False,
#   'raise': False,
#   'rush': False,
#   'steven': True,
#   'tension': False,
#   'amuse': False,
#   'titanic': False,
#   'mouth': False,
#   'suddenly': False,
#   'tim': False,
#   'double': False,
#   'mar': False,
#   'list': False,
#   'today': False,
#   'subtle': False,
#   'brought': False,
#   'hear': False,
#   'road': False,
#   'doctor': False,
#   'hop': False,
#   'suffer': False,
#   'carter': False,
#   'cannot': False,
#   '5': False,
#   'dollar': False,
#   'episode': False,
#   'month': False,
#   'terrible': False,
#   'detective': False,
#   'building': False,
#   'willis': False,
#   'compare': False,
#   'engage': False,
#   'ultimately': False,
#   'opportunity': False,
#   'entirely': False,
#   'key': False,
#   'roll': False,
#   'spielberg': False,
#   'promise': False,
#   'dumb': False,
#   'costume': False,
#   'color': False,
#   'disaster': False,
#   'ghost': False,
#   'cliche': False,
#   'soundtrack': False,
#   'officer': False,
#   '90': True,
#   'store': False,
#   'personality': False,
#   'slightly': False,
#   'fairly': False,
#   'hot': False,
#   'soldier': False,
#   'leader': False,
#   'male': False,
#   'pair': False,
#   'lawyer': False,
#   'sent': False,
#   'spent': False,
#   'complex': False,
#   'machine': False,
#   'awful': False,
#   'max': False,
#   'totally': False,
#   'rescue': False,
#   'recommend': False,
#   'angel': False,
#   'allen': False,
#   'woody': False,
#   'godzilla': False,
#   'ii': False,
#   'thin': False,
#   'delivers': False,
#   'beauty': False,
#   'climax': False,
#   'highly': False,
#   'partner': False,
#   'bug': False,
#   'minor': False,
#   'atmosphere': False,
#   'hill': False,
#   'vega': False,
#   'mike': False,
#   'trip': False,
#   'ridiculous': False,
#   'simon': False,
#   'longer': False,
#   'grant': False,
#   'adam': False,
#   'seven': False,
#   'basic': False,
#   'animal': False,
#   'camp': False,
#   'admit': False,
#   'cheap': False,
#   'six': False,
#   'outside': False,
#   'introduce': False,
#   'plenty': False,
#   'recently': False,
#   'x': False,
#   'realistic': False,
#   'hole': False,
#   'foot': False,
#   'twenty': False,
#   'jackson': True,
#   'clearly': False,
#   'sean': False,
#   'president': False,
#   'indeed': False,
#   'typical': False,
#   'sci': False,
#   'fi': False,
#   'british': False,
#   'flat': False,
#   'spot': False,
#   'period': False,
#   'dress': False,
#   'edit': False,
#   'julia': False,
#   'fit': True,
#   'whatever': False,
#   'edward': False,
#   'kick': False,
#   'lucas': False,
#   'standard': False,
#   'damn': False,
#   'earlier': False,
#   'cameo': False,
#   'concept': False,
#   'creature': False,
#   'quick': False,
#   'brain': True,
#   'buddy': False,
#   'constantly': False,
#   'frame': False,
#   'conclusion': False,
#   'cage': False,
#   'hire': False,
#   'jerry': False,
#   'brief': False,
#   'bore': False,
#   'heavy': False,
#   'college': False,
#   'teacher': False,
#   'energy': False,
#   'medium': False,
#   'tough': False,
#   'ride': False,
#   'wall': False,
#   'target': False,
#   'singer': False,
#   'island': True,
#   'intelligence': False,
#   'cute': False,
#   'lame': False,
#   'century': False,
#   'inspire': False,
#   'green': False,
#   'sing': False,
#   'dull': False,
#   'believable': False,
#   'violent': False,
#   'cinematography': False,
#   'aside': False,
#   'thanks': False,
#   'common': False,
#   'french': False,
#   '1998': False,
#   'appreciate': False,
#   'loud': False,
#   ...},
#  'pos')

# %%
testing_data[0]
# Out:
# ({'film': True,
#   'movie': True,
#   'one': True,
#   'make': True,
#   'like': False,
#   'character': True,
#   'get': False,
#   'see': False,
#   'go': False,
#   'time': False,
#   'well': True,
#   'scene': False,
#   'even': True,
#   'good': True,
#   'story': True,
#   'take': True,
#   'would': False,
#   'much': False,
#   'bad': False,
#   'also': True,
#   'come': False,
#   'give': False,
#   'look': False,
#   'two': False,
#   'way': False,
#   'seem': False,
#   'know': True,
#   'life': False,
#   'first': True,
#   'end': True,
#   'year': False,
#   '--': True,
#   'work': False,
#   'thing': False,
#   'say': True,
#   'plot': True,
#   'really': False,
#   'show': True,
#   'play': False,
#   'little': False,
#   'people': False,
#   'star': True,
#   'could': False,
#   'man': False,
#   'love': False,
#   'try': False,
#   'never': False,
#   'director': False,
#   'best': False,
#   'new': True,
#   'great': True,
#   'many': False,
#   'actor': False,
#   'big': True,
#   'action': True,
#   'watch': False,
#   'want': False,
#   'performance': False,
#   'find': False,
#   'think': False,
#   'u': False,
#   'role': False,
#   'act': False,
#   'another': False,
#   'audience': False,
#   'back': True,
#   'still': False,
#   'something': False,
#   'turn': False,
#   'world': False,
#   'however': False,
#   'old': False,
#   'day': False,
#   'set': False,
#   'every': False,
#   'guy': False,
#   'though': True,
#   'use': False,
#   'comedy': False,
#   'cast': True,
#   'enough': False,
#   'feel': False,
#   'begin': False,
#   'interest': True,
#   'part': False,
#   'actually': False,
#   'young': False,
#   'name': False,
#   'last': True,
#   'real': False,
#   'point': True,
#   'around': False,
#   'run': False,
#   'script': True,
#   'funny': True,
#   'effect': True,
#   'fact': False,
#   'right': False,
#   'may': False,
#   'write': False,
#   'long': False,
#   'woman': False,
#   'lot': False,
#   'minute': False,
#   'friend': False,
#   'place': True,
#   'almost': False,
#   'john': False,
#   'screen': True,
#   'nothing': True,
#   'line': False,
#   'moment': False,
#   'since': False,
#   'become': False,
#   'call': False,
#   'played': False,
#   'ever': False,
#   'tell': False,
#   'start': True,
#   'although': False,
#   'family': False,
#   'help': True,
#   'kill': False,
#   'original': False,
#   'without': False,
#   'problem': False,
#   'three': False,
#   'lead': True,
#   'picture': False,
#   'least': True,
#   'high': False,
#   'laugh': False,
#   'girl': False,
#   'sequence': False,
#   'need': False,
#   'might': False,
#   'away': False,
#   'fall': False,
#   'far': False,
#   'quite': False,
#   'put': False,
#   'course': False,
#   'american': False,
#   'keep': True,
#   'child': False,
#   'bit': False,
#   'rather': False,
#   'attempt': False,
#   'alien': False,
#   'include': False,
#   'always': True,
#   'kind': False,
#   'job': False,
#   'must': False,
#   'follow': False,
#   'special': False,
#   'anything': False,
#   'war': False,
#   'hour': False,
#   'yet': False,
#   'hard': False,
#   'wife': False,
#   'fun': False,
#   'feature': True,
#   'black': False,
#   'home': False,
#   'reason': False,
#   'instead': False,
#   'hand': False,
#   'head': False,
#   'hollywood': False,
#   'sense': False,
#   'lose': False,
#   'probably': False,
#   'men': False,
#   'kid': False,
#   'human': True,
#   'half': True,
#   'shot': False,
#   'mind': True,
#   'series': True,
#   'idea': False,
#   'move': False,
#   'pretty': False,
#   'involve': True,
#   'face': False,
#   'night': False,
#   'let': False,
#   'along': True,
#   'dialogue': False,
#   'direct': True,
#   'talk': False,
#   'everything': False,
#   'together': False,
#   'force': False,
#   'sure': True,
#   'believe': True,
#   'whole': True,
#   'money': False,
#   'sex': False,
#   'second': False,
#   'music': False,
#   'release': False,
#   'question': False,
#   'horror': False,
#   'becomes': True,
#   'father': False,
#   'save': False,
#   'thought': False,
#   'everyone': True,
#   'fight': False,
#   'appear': False,
#   'mother': False,
#   'city': False,
#   'boy': False,
#   'death': False,
#   'do': False,
#   'evil': False,
#   'next': True,
#   'especially': True,
#   'small': False,
#   'perhaps': False,
#   'eye': False,
#   'happen': False,
#   'brother': False,
#   'base': True,
#   'relationship': False,
#   'expect': False,
#   'couple': False,
#   'less': True,
#   'case': False,
#   'writer': False,
#   'different': False,
#   'meet': True,
#   'rest': True,
#   'change': False,
#   'mean': False,
#   'joke': False,
#   'sound': False,
#   'review': True,
#   '2': False,
#   '10': False,
#   'whose': True,
#   'late': True,
#   'completely': False,
#   'care': True,
#   'create': False,
#   'fan': False,
#   'book': False,
#   'several': False,
#   'comic': False,
#   'michael': True,
#   'anyone': True,
#   'word': False,
#   'school': False,
#   'live': False,
#   'hit': False,
#   'suppose': False,
#   'left': False,
#   'add': False,
#   'true': False,
#   'simply': False,
#   'game': False,
#   'main': True,
#   'entertain': True,
#   'top': False,
#   'humor': False,
#   'someone': False,
#   'lack': False,
#   'mr': False,
#   'car': False,
#   'matter': True,
#   'tv': True,
#   'leave': False,
#   'found': False,
#   'house': False,
#   'either': False,
#   'james': True,
#   'wrong': False,
#   'side': False,
#   'often': False,
#   'support': False,
#   'town': False,
#   'viewer': False,
#   'group': False,
#   'wonder': False,
#   'david': False,
#   'else': True,
#   'power': True,
#   'enjoy': False,
#   'hero': False,
#   'full': False,
#   'deal': False,
#   'robert': False,
#   'present': False,
#   'later': False,
#   'result': False,
#   'credit': False,
#   'behind': False,
#   'final': False,
#   'soon': False,
#   'dead': False,
#   'camera': False,
#   'scream': False,
#   'open': False,
#   'unfortunately': True,
#   'provide': False,
#   'murder': False,
#   'able': False,
#   'son': False,
#   'style': False,
#   'summer': False,
#   'element': False,
#   'despite': False,
#   'entire': False,
#   'nice': False,
#   'team': False,
#   'theater': False,
#   'return': False,
#   'stop': False,
#   'finally': False,
#   'maybe': False,
#   'die': False,
#   'order': False,
#   'person': False,
#   'past': False,
#   'miss': False,
#   'situation': False,
#   'title': True,
#   'view': False,
#   'example': False,
#   'perfect': False,
#   'cop': False,
#   'certainly': False,
#   'sort': False,
#   'joe': False,
#   'fine': False,
#   'version': False,
#   'stand': False,
#   'worth': False,
#   'note': True,
#   'piece': False,
#   'classic': False,
#   'cut': False,
#   'hope': False,
#   'video': False,
#   'consider': False,
#   'bring': False,
#   'drama': False,
#   'self': False,
#   'major': False,
#   'voice': False,
#   'early': False,
#   'white': False,
#   'beautiful': False,
#   'strong': False,
#   'production': True,
#   'body': False,
#   'event': False,
#   'upon': False,
#   'five': False,
#   'violence': True,
#   'heart': False,
#   'break': False,
#   'talent': False,
#   'killer': False,
#   'screenplay': False,
#   'daughter': False,
#   'nearly': False,
#   'short': False,
#   'close': False,
#   'wait': False,
#   'already': False,
#   'level': False,
#   'pull': False,
#   'ship': False,
#   'dark': False,
#   'room': False,
#   'four': False,
#   'deep': True,
#   'opening': False,
#   'thriller': False,
#   'light': False,
#   'age': False,
#   'obvious': False,
#   'dog': False,
#   'ask': False,
#   'disney': False,
#   'king': False,
#   'experience': False,
#   'chase': False,
#   'earth': True,
#   'learn': False,
#   'offer': False,
#   'guess': False,
#   'state': False,
#   'surprise': False,
#   'waste': False,
#   'throughout': False,
#   'figure': False,
#   'number': False,
#   'exactly': False,
#   'kevin': False,
#   'jack': False,
#   'others': False,
#   '1': False,
#   'hold': False,
#   'form': False,
#   'flick': False,
#   'plan': False,
#   'direction': False,
#   'romantic': False,
#   'twist': False,
#   'pace': False,
#   'art': True,
#   'realize': False,
#   'easy': False,
#   'computer': False,
#   'sometimes': False,
#   'career': False,
#   'dream': False,
#   'simple': False,
#   'fill': False,
#   'type': False,
#   'walk': False,
#   'filmmaker': False,
#   'touch': False,
#   'novel': False,
#   'gun': False,
#   'jackie': False,
#   'charm': False,
#   'planet': False,
#   'win': False,
#   'husband': False,
#   'rise': False,
#   'score': False,
#   'boring': False,
#   'tom': False,
#   'space': True,
#   'member': True,
#   'saw': False,
#   'carry': True,
#   'paul': False,
#   'truly': False,
#   'york': False,
#   'tale': False,
#   'oscar': False,
#   'drug': False,
#   'possible': False,
#   'battle': True,
#   'hell': False,
#   'peter': False,
#   'sequel': False,
#   'song': False,
#   'material': False,
#   'focus': False,
#   'wild': False,
#   'remember': False,
#   '3': False,
#   'decide': False,
#   'chance': False,
#   'extremely': False,
#   'rock': False,
#   'genre': False,
#   'smith': False,
#   'god': False,
#   'particularly': False,
#   'police': False,
#   'quickly': False,
#   'de': False,
#   'manages': False,
#   'attention': False,
#   'parent': False,
#   'stupid': False,
#   'happens': False,
#   'lee': False,
#   'shoot': False,
#   'escape': False,
#   'pay': True,
#   'usually': False,
#   'stay': True,
#   'none': False,
#   'mostly': True,
#   'fiction': False,
#   'villain': False,
#   'studio': True,
#   'yes': False,
#   'success': True,
#   'girlfriend': False,
#   'dr': True,
#   'flaw': False,
#   'cover': False,
#   'quality': False,
#   'image': False,
#   'detail': False,
#   'single': False,
#   'project': False,
#   'television': True,
#   'million': False,
#   'large': False,
#   'eventually': False,
#   'slow': False,
#   'co': False,
#   'except': False,
#   'middle': True,
#   'steal': False,
#   'mention': False,
#   'sit': False,
#   'low': False,
#   'across': False,
#   'van': False,
#   'law': False,
#   'theme': False,
#   'alone': False,
#   'crime': False,
#   'read': False,
#   'actress': False,
#   'attack': False,
#   'future': False,
#   'obviously': False,
#   'told': False,
#   'secret': False,
#   'oh': False,
#   'within': False,
#   'premise': False,
#   'water': False,
#   'williams': False,
#   'understand': False,
#   'complete': False,
#   'drive': False,
#   'impressive': False,
#   'recent': False,
#   'explain': False,
#   'mystery': False,
#   'emotional': False,
#   'batman': False,
#   'robin': False,
#   'amaze': False,
#   'history': True,
#   'science': False,
#   'cause': False,
#   'company': False,
#   'poor': False,
#   'living': False,
#   'wonderful': False,
#   'easily': True,
#   'somehow': False,
#   'country': False,
#   'important': False,
#   'effort': False,
#   'wish': False,
#   'aspect': False,
#   'office': False,
#   'harry': False,
#   'cool': False,
#   '4': False,
#   'street': False,
#   'ryan': False,
#   'control': False,
#   'among': False,
#   'motion': False,
#   'agent': False,
#   'whether': False,
#   'local': False,
#   'america': False,
#   'lie': False,
#   'fire': False,
#   'message': False,
#   'chris': False,
#   'mark': False,
#   'wedding': False,
#   'subject': False,
#   'fear': False,
#   'difficult': False,
#   'cross': False,
#   'jones': False,
#   'rich': False,
#   'serious': False,
#   'doubt': False,
#   'murphy': False,
#   'fast': False,
#   'entertainment': False,
#   'fail': False,
#   'happy': False,
#   'screenwriter': False,
#   'ben': False,
#   'near': True,
#   'third': False,
#   'critic': False,
#   'brings': False,
#   'class': False,
#   'reality': False,
#   'hilarious': False,
#   'dramatic': False,
#   'george': False,
#   'stuff': False,
#   'throw': False,
#   'basically': False,
#   'surprisingly': False,
#   'due': False,
#   'fly': False,
#   'produce': False,
#   'suspense': False,
#   'annoy': False,
#   'us': False,
#   'trouble': False,
#   'certain': False,
#   'william': False,
#   'ago': False,
#   'speak': False,
#   'answer': False,
#   'apparently': False,
#   'sexual': False,
#   'previous': True,
#   'bill': False,
#   'crew': True,
#   'similar': False,
#   'vampire': False,
#   'jim': False,
#   'budget': True,
#   'intelligent': False,
#   'emotion': True,
#   'general': False,
#   'smart': False,
#   'presence': False,
#   'blood': False,
#   'choice': False,
#   'business': False,
#   'appeal': False,
#   'personal': False,
#   'confuse': False,
#   'bob': False,
#   'visual': True,
#   'predictable': False,
#   'clear': False,
#   'party': False,
#   'decides': False,
#   'mission': False,
#   'producer': False,
#   'tone': False,
#   'wear': False,
#   'clever': False,
#   'approach': False,
#   'teen': False,
#   'scary': False,
#   'somewhat': False,
#   'beyond': False,
#   'romance': False,
#   'leaf': False,
#   'familiar': True,
#   'deliver': False,
#   'la': False,
#   'excellent': False,
#   'rat': False,
#   'sister': False,
#   'red': False,
#   'prison': False,
#   'favorite': False,
#   'date': False,
#   'ability': False,
#   'share': True,
#   'absolutely': False,
#   'excite': True,
#   'r': False,
#   'adult': False,
#   'successful': False,
#   'cinema': False,
#   'b': False,
#   'catch': False,
#   'giant': False,
#   'treat': False,
#   'frank': False,
#   'allow': False,
#   'mess': False,
#   'popular': True,
#   'discover': False,
#   'rule': False,
#   'anyway': False,
#   'box': False,
#   'potential': False,
#   'strike': False,
#   'trek': True,
#   'strange': False,
#   'effective': False,
#   'definitely': True,
#   'student': False,
#   'private': False,
#   'amount': False,
#   'nature': False,
#   'trailer': False,
#   'eddie': False,
#   'felt': False,
#   'immediately': False,
#   'shock': False,
#   'powerful': False,
#   'truman': False,
#   'victim': False,
#   'fails': False,
#   'thrill': False,
#   'hate': False,
#   'handle': False,
#   'free': False,
#   'continue': True,
#   'former': False,
#   'master': False,
#   'usual': False,
#   'seriously': False,
#   'appearance': False,
#   'track': False,
#   'martin': False,
#   'scott': False,
#   'pick': False,
#   'search': False,
#   'development': False,
#   'capture': False,
#   'blue': False,
#   'join': False,
#   'rating': True,
#   'neither': False,
#   'stone': False,
#   'week': False,
#   'sam': False,
#   'manage': False,
#   'huge': False,
#   'truth': False,
#   'convincing': False,
#   'grace': False,
#   'issue': False,
#   'straight': False,
#   'race': True,
#   'inside': False,
#   'solid': False,
#   'musical': False,
#   'unlike': False,
#   'perfectly': False,
#   'sweet': False,
#   'sign': False,
#   'enjoyable': False,
#   'animate': False,
#   'hunt': False,
#   'door': False,
#   'kiss': False,
#   'ape': False,
#   'purpose': False,
#   'serve': False,
#   'air': False,
#   'spend': False,
#   'reveal': False,
#   'haunt': False,
#   'cameron': False,
#   'otherwise': False,
#   'married': False,
#   'land': False,
#   'prove': False,
#   'gag': False,
#   'non': False,
#   'toy': False,
#   'suspect': False,
#   'decent': False,
#   'political': False,
#   'dance': False,
#   'grow': False,
#   'ex': False,
#   'sight': False,
#   'overall': False,
#   'front': False,
#   'merely': False,
#   'travel': True,
#   'likely': False,
#   'army': False,
#   'animation': False,
#   'drop': False,
#   'nick': False,
#   'west': False,
#   'imagine': False,
#   'depth': False,
#   'bunch': False,
#   'park': False,
#   'l': False,
#   'ten': False,
#   'reach': False,
#   'female': False,
#   'heard': False,
#   'government': False,
#   'require': False,
#   'society': False,
#   'bruce': False,
#   'baby': False,
#   'train': False,
#   'arm': False,
#   'e': True,
#   'pop': False,
#   'sell': False,
#   'respect': False,
#   'english': False,
#   'particular': True,
#   'towards': False,
#   'design': True,
#   'lover': False,
#   'background': False,
#   'fashion': False,
#   'adventure': True,
#   'richard': False,
#   'brilliant': False,
#   'actual': False,
#   'term': False,
#   'monster': False,
#   'struggle': False,
#   'silly': False,
#   'chan': False,
#   'ground': False,
#   'steve': False,
#   'various': False,
#   'spirit': False,
#   'succeed': False,
#   'award': False,
#   'modern': False,
#   'player': False,
#   'menace': False,
#   'queen': True,
#   'club': False,
#   'cold': False,
#   'talented': False,
#   'step': False,
#   'impact': False,
#   '8': False,
#   'memorable': False,
#   'impossible': False,
#   'raise': False,
#   'rush': False,
#   'steven': False,
#   'tension': False,
#   'amuse': False,
#   'titanic': False,
#   'mouth': False,
#   'suddenly': False,
#   'tim': False,
#   'double': False,
#   'mar': False,
#   'list': False,
#   'today': False,
#   'subtle': False,
#   'brought': False,
#   'hear': False,
#   'road': False,
#   'doctor': False,
#   'hop': False,
#   'suffer': False,
#   'carter': False,
#   'cannot': False,
#   '5': False,
#   'dollar': False,
#   'episode': False,
#   'month': False,
#   'terrible': False,
#   'detective': False,
#   'building': False,
#   'willis': False,
#   'compare': False,
#   'engage': True,
#   'ultimately': False,
#   'opportunity': False,
#   'entirely': False,
#   'key': False,
#   'roll': True,
#   'spielberg': False,
#   'promise': False,
#   'dumb': False,
#   'costume': False,
#   'color': False,
#   'disaster': False,
#   'ghost': False,
#   'cliche': False,
#   'soundtrack': False,
#   'officer': False,
#   '90': False,
#   'store': False,
#   'personality': False,
#   'slightly': False,
#   'fairly': False,
#   'hot': False,
#   'soldier': False,
#   'leader': False,
#   'male': False,
#   'pair': False,
#   'lawyer': False,
#   'sent': False,
#   'spent': False,
#   'complex': False,
#   'machine': False,
#   'awful': False,
#   'max': False,
#   'totally': False,
#   'rescue': False,
#   'recommend': False,
#   'angel': False,
#   'allen': False,
#   'woody': False,
#   'godzilla': False,
#   'ii': False,
#   'thin': False,
#   'delivers': True,
#   'beauty': False,
#   'climax': False,
#   'highly': False,
#   'partner': False,
#   'bug': False,
#   'minor': False,
#   'atmosphere': False,
#   'hill': False,
#   'vega': False,
#   'mike': False,
#   'trip': False,
#   'ridiculous': False,
#   'simon': False,
#   'longer': False,
#   'grant': False,
#   'adam': False,
#   'seven': False,
#   'basic': False,
#   'animal': False,
#   'camp': False,
#   'admit': False,
#   'cheap': False,
#   'six': False,
#   'outside': False,
#   'introduce': False,
#   'plenty': False,
#   'recently': False,
#   'x': False,
#   'realistic': False,
#   'hole': False,
#   'foot': False,
#   'twenty': False,
#   'jackson': False,
#   'clearly': False,
#   'sean': False,
#   'president': False,
#   'indeed': False,
#   'typical': True,
#   'sci': True,
#   'fi': True,
#   'british': False,
#   'flat': False,
#   'spot': False,
#   'period': False,
#   'dress': False,
#   'edit': False,
#   'julia': False,
#   'fit': False,
#   'whatever': False,
#   'edward': False,
#   'kick': False,
#   'lucas': False,
#   'standard': False,
#   'damn': False,
#   'earlier': False,
#   'cameo': False,
#   'concept': False,
#   'creature': False,
#   'quick': False,
#   'brain': False,
#   'buddy': False,
#   'constantly': False,
#   'frame': False,
#   'conclusion': False,
#   'cage': False,
#   'hire': False,
#   'jerry': False,
#   'brief': False,
#   'bore': False,
#   'heavy': False,
#   'college': False,
#   'teacher': False,
#   'energy': False,
#   'medium': False,
#   'tough': False,
#   'ride': False,
#   'wall': False,
#   'target': False,
#   'singer': False,
#   'island': False,
#   'intelligence': False,
#   'cute': False,
#   'lame': False,
#   'century': True,
#   'inspire': False,
#   'green': False,
#   'sing': False,
#   'dull': False,
#   'believable': False,
#   'violent': False,
#   'cinematography': False,
#   'aside': False,
#   'thanks': False,
#   'common': False,
#   'french': False,
#   '1998': False,
#   'appreciate': False,
#   'loud': False,
#   ...},
#  'pos')

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier, testing_data)
# Out:
# 0.77

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#                ludicrous = True              neg : pos    =     12.5 : 1.0
#                stupidity = True              neg : pos    =     10.5 : 1.0
#              outstanding = True              pos : neg    =      8.9 : 1.0
#              beautifully = True              pos : neg    =      7.9 : 1.0
#                  idiotic = True              neg : pos    =      7.8 : 1.0
#                    mulan = True              pos : neg    =      7.7 : 1.0
#                   turkey = True              neg : pos    =      7.5 : 1.0
#              wonderfully = True              pos : neg    =      7.2 : 1.0
#                   martha = True              neg : pos    =      7.0 : 1.0
#                      era = True              pos : neg    =      6.9 : 1.0
#                   seagal = True              neg : pos    =      6.6 : 1.0
#                    anger = True              pos : neg    =      6.4 : 1.0
#                   welles = True              neg : pos    =      6.3 : 1.0
#                     anna = True              pos : neg    =      6.2 : 1.0
#               schumacher = True              neg : pos    =      6.2 : 1.0

# %% [markdown]
# # NLP - 2 (Using SklearnClassifier with NLTK)

# %%
from sklearn.svm  import SVC
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc = SVC()
classifier_sklearn = SklearnClassifier(svc)

# %%
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC())>

# %%
nltk.classify.accuracy(classifier_sklearn, testing_data)
# Out:
# 0.832

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
classifier_sklearn1 = SklearnClassifier(rfc)

# %%
classifier_sklearn1.train(training_data)
# Out:
# <SklearnClassifier(RandomForestClassifier())>

# %%
nltk.classify.accuracy(classifier_sklearn1, testing_data)
# Out:
# 0.792

# %% [markdown]
# ### go to NLP - 2 folder and see the same result of SklearnClassifier and RandomForestClassifier (see the accuracy of both classifiers)
